# %% [markdown]
# # Example: Compute the Probability of Profit for a Single Options Contract
# Fill me in

# %% [markdown]
# ## Setup
# Set up the computational environment by including the `Include.jl` file. The `Include.jl` file loads external packages, various functions we will use in the exercise, and custom types to model the components of our example problem.
# * For additional information on functions and types used in this material, see the [Julia programming language documentation](https://docs.julialang.org/en/v1/) and the [VLQuantitativeFinancePackage.jl documentation](https://github.com/varnerlab/VLQuantitativeFinancePackage.jl).

# %%
include("Include.jl");
# Out:
#     Updating git-repo `https://github.com/varnerlab/VLQuantitativeFinancePackage.jl.git`
#    Resolving package versions...
#   No Changes to `~/Desktop/julia_work/CHEME-130-eCornell-Repository/courses/CHEME-134/module-2/Project.toml`
#   No Changes to `~/Desktop/julia_work/CHEME-130-eCornell-Repository/courses/CHEME-134/module-2/Manifest.toml`
#   Activating project at `~/Desktop/julia_work/CHEME-130-eCornell-Repository/courses/CHEME-134/module-2`
#   No Changes to `~/Desktop/julia_work/CHEME-130-eCornell-Repository/courses/CHEME-134/module-2/Project.toml`
#   No Changes to `~/Desktop/julia_work/CHEME-130-eCornell-Repository/courses/CHEME-134/module-2/Manifest.toml`
#     Updating registry at `~/.julia/registries/General.toml`
#     Updating git-repo `https://github.com/varnerlab/VLQuantitativeFinancePackage.jl.git`
#   No Changes to `~/Desktop/julia_work/CHEME-130-eCornell-Repository/courses/CHEME-134/module-2/Project.toml`
#   No Changes to `~/Desktop/julia_work/CHEME-130-eCornell-Repository/courses/CHEME-134/module-2/Manifest.toml`

# %% [markdown]
# ## Prerequisites
# Before doing anything else, load the options chain dataset using the `MyOptionsChainDataSet()` function. This function returns the pricing data as a [Julia Dictionary type](https://docs.julialang.org/en/v1/base/collections/#Dictionaries) with `keys` holding the number of days to expiration `DTE::Int64` and `values` being a [Vector](https://docs.julialang.org/en/v1/base/arrays/#Base.Vector-Tuple{UndefInitializer,%20Any}) of multilevel dictionaries. We'll store the options contract price data in the `dataset` variable.
# * In this example, we'll use options pricing data for [Tesla](https://finance.yahoo.com/quote/TSLA/) as the underlying asset. The `dataset` variable holds pricing information for `call` and `put` contracts. Each contract has a different strike price. In addition to the contract price, there is additional information about the underlying asset and contract.
# * For any given `DTE` key, the price data is organized as a `Vector{Dict{String, Any}},` where each element in the vector corresponds to a different strike price, and each strike price is a dictionary with keys: `day,` `details,` `last_quote,` `last_trade,` `underlying_asset,` `open_interest` and `break_even_price.` Each key (except for the `open_interest` and `break_even_price` keys) points to another dictionary.

# %%
dataset = MyOptionsChainDataSet()
# Out:
# Dict{Int64, Vector{Dict{String, Any}}} with 17 entries:
#   123 => [Dict("day"=>Dict{String, Any}(), "details"=>Dict{String, Any}("contra…
#   60  => [Dict("day"=>Dict{String, Any}(), "details"=>Dict{String, Any}("contra…
#   32  => [Dict("day"=>Dict{String, Any}("change"=>0, "high"=>240.85, "change_pe…
#   11  => [Dict("day"=>Dict{String, Any}("change"=>0, "high"=>144.01, "change_pe…
#   368 => [Dict("day"=>Dict{String, Any}("change"=>0, "high"=>513.88, "change_pe…
#   578 => [Dict("day"=>Dict{String, Any}("change"=>0, "high"=>350.37, "change_pe…
#   214 => [Dict("day"=>Dict{String, Any}("change"=>0, "high"=>627.95, "change_pe…
#   270 => [Dict("day"=>Dict{String, Any}("change"=>0, "high"=>341.78, "change_pe…
#   459 => [Dict("day"=>Dict{String, Any}("change"=>0, "high"=>244.4, "change_per…
#   39  => [Dict("day"=>Dict{String, Any}(), "details"=>Dict{String, Any}("contra…
#   732 => [Dict("day"=>Dict{String, Any}("change"=>0, "high"=>246.45, "change_pe…
#   914 => [Dict("day"=>Dict{String, Any}("change"=>0, "high"=>248.35, "change_pe…
#   25  => [Dict("day"=>Dict{String, Any}(), "details"=>Dict{String, Any}("contra…
#   151 => [Dict("day"=>Dict{String, Any}("change"=>0, "high"=>251.05, "change_pe…
#   4   => [Dict("day"=>Dict{String, Any}("change"=>0, "high"=>141.8, "change_per…
#   18  => [Dict("day"=>Dict{String, Any}("change"=>0, "high"=>145.15, "change_pe…
#   88  => [Dict("day"=>Dict{String, Any}("change"=>0, "high"=>590.3, "change_per…

# %%
dataset[60][50]
# Out:
# Dict{String, Any} with 9 entries:
#   "day"                => Dict{String, Any}("change"=>0, "high"=>6.7, "change_p…
#   "details"            => Dict{String, Any}("contract_type"=>"put", "ticker"=>"…
#   "last_quote"         => Dict{String, Any}("midpoint"=>6.125, "ask"=>6.2, "tim…
#   "last_trade"         => Dict{String, Any}("timeframe"=>"REAL-TIME", "exchange…
#   "underlying_asset"   => Dict{String, Any}("timeframe"=>"REAL-TIME", "ticker"=…
#   "greeks"             => Dict{String, Any}("theta"=>-0.126845, "gamma"=>0.0036…
#   "open_interest"      => 3898
#   "implied_volatility" => 0.627397
#   "break_even_price"   => 203.875

# %%
list_of_options_chains = Dict{Int64,DataFrame}();
DTEs = keys(dataset) |> collect |> sort;
for dte_value ∈ DTEs

    dataframe = search(dataset, dte_value, (DTE::Int64, record::Dict{String, Any}) -> begin

            # initialize -
            should_keep_record = false;

            # what is the strike?
            K = record["details"]["strike_price"];
            if (record["details"]["contract_type"] == "put" && 60.0 ≤ K ≤ 800.0)
                should_keep_record = true
            end;
            
            # return -
            return should_keep_record;
        end
    );
    list_of_options_chains[dte_value] = dataframe;
end

# %%
list_of_options_contracts = list_of_options_chains[60]
list_of_options_contracts[50,:]
# Out:
# DataFrameRow
#  Row │ underlying  strike   type    IV        bid      ask      midpoint  brea ⋯
#      │ Float64     Float64  String  Float64   Float64  Float64  Float64   Floa ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#   50 │     261.49    210.0  put     0.627397     6.05      6.2     6.125       ⋯
#                                                                3 columns omitted

# %% [markdown]
# Parameters

# %%
Δt = (1.0/252.0);
risk_free_rate = 0.0431; # 10-year treasury note

# %% [markdown]
# ## Task 1: Compute the break-even points for a short TSLA put
# Suppose you sold a `DTE = 65-day` put option on `TSLA,` and you collected the mid-point premium for the sale. Let's use options data  to compute the breakeven point for the contract, i.e., the value of the `TSLA` share price where you start to lose money on the trade as a function of the strike price `K.`

# %%
contractmodel = build(MyAmericanPutContractModel, (
    K = 0.0,
    premium = 0.0
));

# %%
number_of_contracts = nrow(list_of_options_contracts);
for i ∈ 1:number_of_contracts

    contractmodel.K = list_of_options_contracts[i, :strike]
    contractmodel.premium = list_of_options_contracts[i,:midpoint]
    breakeven_computed = contractmodel.K - contractmodel.premium
    @show (breakeven_computed,list_of_options_contracts[i, :break_even_price])
    
end
# Out:
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (260.8, 260.8)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (260.775, 260.775)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (260.75, 260.75)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (260.625, 260.625)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (260.45, 260.45)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (260.2, 260.2)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (260.325, 260.325)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (259.95, 259.95)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (259.8, 259.8)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (259.6, 259.6)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (259.45, 259.45)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (259.325, 259.325)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (259.15, 259.15)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (259.0, 259.0)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (258.825, 258.825)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (258.1, 258.1)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (257.725, 257.725)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (257.95, 257.95)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (257.725, 257.725)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (257.425, 257.425)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (257.05, 257.05)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (256.7, 256.7)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (256.9, 256.9)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (255.925, 255.925)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (255.425, 255.425)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (254.9, 254.9)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (254.1, 254.1)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (253.4, 253.4)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (252.65, 252.65)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (251.75, 251.75)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (251.1, 251.1)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (249.7, 249.7)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (248.55, 248.55)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (247.275, 247.275)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (246.3, 246.3)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (244.275, 244.275)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (243.4, 243.4)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (240.625, 240.625)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (238.55, 238.55)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (236.3, 236.3)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (233.85, 233.85)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (231.225, 231.225)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (228.4, 228.4)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (225.4, 225.4)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (222.55, 222.55)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (218.85, 218.85)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (215.35, 215.35)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (211.675, 211.675)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (207.825, 207.825)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (203.875, 203.875)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (199.775, 199.775)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (195.55, 195.55)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (191.2, 191.2)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (186.8, 186.8)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (182.265, 182.265)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (177.685, 177.685)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (173.05, 173.05)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (168.345, 168.345)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (163.6, 163.6)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (158.82, 158.82)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (153.99, 153.99)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (149.145, 149.145)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (144.265, 144.265)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (139.37, 139.37)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (134.45, 134.45)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (129.535, 129.535)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (124.605, 124.605)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (119.66, 119.66)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (114.695, 114.695)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (109.75, 109.75)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (104.79, 104.79)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (99.815, 99.815)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (94.84, 94.84)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (89.87, 89.87)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (84.885, 84.885)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (79.905, 79.905)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (74.92, 74.92)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (69.94, 69.94)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (64.95, 64.95)
# (breakeven_computed, list_of_options_contracts[i, :break_even_price]) = (59.96, 59.96)

# %% [markdown]
# ## Task 2: Construct a single asset geometric Brownian motion of TSLA share price
# Fill me in

# %%
parameters_df = CSV.read(joinpath(_PATH_TO_DATA, "gbmparameters", "Parameters-SP500-2018-2023.csv"), DataFrame);

# %% [markdown]
# Construct gbm

# %%
model = build(MyGeometricBrownianMotionEquityModel, (
    μ = 0.05,
    σ = filter(:ticker=> x-> x=="TSLA", parameters_df)[!,:volatility] |> first
));

# %% [markdown]
# Sample

# %%
number_of_samples = 5000;
endpoint = VLQuantitativeFinancePackage.sample(model, (
    T₁ = 0.0,
    T₂ = (65.0)*(Δt),
    Δt = Δt,
    Sₒ = Sₒ
), number_of_paths = number_of_samples) |> samples -> samples[end,2:end]; # get last row from col 2 -> number_of_paths

# %% [markdown]
# Unhide

# %%
d = fit_mle(LogNormal, endpoint)
# Out:
# LogNormal{Float64}(μ=5.155611308620953, σ=0.28360357153642884)

# %% [markdown]
# `Unhide` me

# %%
let
    density(endpoint, lw=2, c=:deepskyblue1, label="GBM simulation (N = 5000)")
    plot!(d, lw=2, label="MLE LogNormal", c=:red)
    xlabel!("Share price T = 60 days (USD/share)", fontsize=18)
    ylabel!("Probability Density (AU)", fontsize=18)
end

# %%
cdf_model_gbm = cdf(d, sort(endpoint));

# %%
plot(sort(endpoint), cdf_model_gbm)

# %% [markdown]
# ## Task 3: Share price projection using the implied volatility
# Fill me in

# %% [markdown]
# ## Task 4: Estimate the probability of profit as a function of the strike price
# Fill me in

# %%
IV = (58.64/100);
DTE = 65.0;
Sₒ = 178.0
dIV = Normal(Sₒ, Sₒ*IV*sqrt(DTE/252));

# %%
cdf_model_IV = cdf(dIV,0:400 |> collect);
plot(0:300 |> collect, cdf_model_IV)

# %%
for i ∈ 1:number_of_contracts
    K = list_of_options_contracts[i, :strike];
    P = list_of_options_contracts[i,:midpoint];
    ℬ = list_of_options_contracts[i, :break_even_price];
    @show i, K, Sₒ, P, ℬ, cdf(d,K), cdf(d,ℬ)
end
# Out:
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (1, 500.0, 178.0, 239.2, 260.8, 0.9999057965400299, 0.9249432098853891)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (2, 490.0, 178.0, 229.225, 260.775, 0.9998752820976403, 0.9248953221403964)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (3, 480.0, 178.0, 219.25, 260.75, 0.9998347459292849, 0.9248474065055539)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (4, 470.0, 178.0, 209.375, 260.625, 0.999780865792057, 0.9246074095130655)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (5, 460.0, 178.0, 199.55, 260.45, 0.9997092144974375, 0.9242702385834326)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (6, 450.0, 178.0, 189.8, 260.2, 0.9996138943773298, 0.9237861791669886)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (7, 440.0, 178.0, 179.675, 260.325, 0.9994870530409148, 0.9240285605291305)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (8, 430.0, 178.0, 170.05, 259.95, 0.9993182434051923, 0.9232992997621856)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (9, 420.0, 178.0, 160.2, 259.8, 0.9990935803694438, 0.9230058128955672)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (10, 410.0, 178.0, 150.4, 259.6, 0.9987946333910201, 0.92261290523701)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (11, 405.0, 178.0, 145.55, 259.45, 0.9986099530665289, 0.9223170268115493)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (12, 400.0, 178.0, 140.675, 259.325, 0.9983969783419888, 0.9220696748907438)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (13, 395.0, 178.0, 135.85, 259.15, 0.9981514109438407, 0.9217221774657834)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (14, 390.0, 178.0, 131.0, 259.0, 0.9978683133148402, 0.9214232006528275)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (15, 385.0, 178.0, 126.175, 258.825, 0.9975420174594402, 0.921073081367549)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (16, 380.0, 178.0, 121.9, 258.1, 0.9971660218207662, 0.9196074235193705)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (17, 375.0, 178.0, 117.275, 257.725, 0.9967328748802772, 0.9188396612296359)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (18, 370.0, 178.0, 112.05, 257.95, 0.9962340440967743, 0.9193011135896427)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (19, 365.0, 178.0, 107.275, 257.725, 0.995659768743271, 0.9188396612296359)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (20, 360.0, 178.0, 102.575, 257.425, 0.9949988951662834, 0.9182206657914683)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (21, 355.0, 178.0, 97.95, 257.05, 0.99423869299231, 0.917440900182272)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (22, 350.0, 178.0, 93.3, 256.7, 0.9933646508530588, 0.9167070441850715)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (23, 345.0, 178.0, 88.1, 256.9, 0.992360250309637, 0.9171271110083002)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (24, 340.0, 178.0, 84.075, 255.925, 0.9912067168450692, 0.9150610099222092)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (25, 335.0, 178.0, 79.575, 255.425, 0.9898827470865292, 0.9139834932656841)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (26, 330.0, 178.0, 75.1, 254.9, 0.9883642118402066, 0.9128388215758342)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (27, 325.0, 178.0, 70.9, 254.1, 0.9866238351040295, 0.9110681104164582)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (28, 320.0, 178.0, 66.6, 253.4, 0.9846308500027231, 0.9094922154930203)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (29, 315.0, 178.0, 62.35, 252.65, 0.9823506336071411, 0.9077759135601214)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (30, 310.0, 178.0, 58.25, 251.75, 0.9797443239015792, 0.9056777958670787)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (31, 305.0, 178.0, 53.9, 251.1, 0.9767684237993386, 0.9041359736093467)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (32, 300.0, 178.0, 50.3, 249.7, 0.9733743991317835, 0.9007382819911296)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (33, 295.0, 178.0, 46.45, 248.55, 0.9695082800043998, 0.897867341544812)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (34, 290.0, 178.0, 42.725, 247.275, 0.9651102778780808, 0.894598163212107)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (35, 285.0, 178.0, 38.7, 246.3, 0.9601144342420318, 0.8920358829582838)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (36, 280.0, 178.0, 35.725, 244.275, 0.9544483208310881, 0.8865375372315988)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (37, 275.0, 178.0, 31.6, 243.4, 0.9480328160191933, 0.8840863477735763)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (38, 270.0, 178.0, 29.375, 240.625, 0.9407819872751007, 0.8760026261285722)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (39, 265.0, 178.0, 26.45, 238.55, 0.9326031153336906, 0.8696409274607162)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (40, 260.0, 178.0, 23.7, 236.3, 0.9233969018914232, 0.8624251290497058)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (41, 255.0, 178.0, 21.15, 233.85, 0.9130579089686985, 0.8541799151530259)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (42, 250.0, 178.0, 18.775, 231.225, 0.901475284278175, 0.8448818019506479)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (43, 245.0, 178.0, 16.6, 228.4, 0.8885338325435086, 0.8343207491237539)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (44, 240.0, 178.0, 14.6, 225.4, 0.874115497109091, 0.822454668903071)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (45, 235.0, 178.0, 12.45, 222.55, 0.8581013185551281, 0.8105410648058651)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (46, 230.0, 178.0, 11.15, 218.85, 0.8403739363506992, 0.7941133153353865)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (47, 225.0, 178.0, 9.65, 215.35, 0.8208206945715584, 0.7775455485620695)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (48, 220.0, 178.0, 8.325, 211.675, 0.7993374018759711, 0.759046238029021)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (49, 215.0, 178.0, 7.175, 207.825, 0.7758327775623259, 0.7384306805001981)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (50, 210.0, 178.0, 6.125, 203.875, 0.7502335877833133, 0.7159501178325126)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (51, 205.0, 178.0, 5.225, 199.775, 0.7224904370137729, 0.6911876100825957)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (52, 200.0, 178.0, 4.45, 195.55, 0.6925841280138466, 0.6641616472697767)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (53, 195.0, 178.0, 3.8, 191.2, 0.660532437649799, 0.6347744782487836)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (54, 190.0, 178.0, 3.2, 186.8, 0.6263970758071037, 0.6035065651949818)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (55, 185.0, 178.0, 2.735, 182.265, 0.5902905014926103, 0.5697645692158947)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (56, 180.0, 178.0, 2.315, 177.685, 0.5523821674361353, 0.5342823534411958)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (57, 175.0, 178.0, 1.95, 173.05, 0.5129036582954513, 0.49714340501249177)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (58, 170.0, 178.0, 1.655, 168.345, 0.4721520877900002, 0.45844323872130605)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (59, 165.0, 178.0, 1.4, 163.6, 0.43049104082848805, 0.4187197367702916)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (60, 160.0, 178.0, 1.18, 158.82, 0.38834830657093955, 0.3783840969823254)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (61, 155.0, 178.0, 1.01, 153.99, 0.3462096701605989, 0.3377449813058194)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (62, 150.0, 178.0, 0.855, 149.145, 0.3046081401364751, 0.2975886643341173)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (63, 145.0, 178.0, 0.735, 144.265, 0.2641082107709942, 0.25828235366673175)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (64, 140.0, 178.0, 0.63, 139.37, 0.22528511441616866, 0.22054089304563335)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (65, 135.0, 178.0, 0.55, 134.45, 0.18869951732965073, 0.18483450844661733)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (66, 130.0, 178.0, 0.465, 129.535, 0.15486874180487226, 0.15187896357951383)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (67, 125.0, 178.0, 0.395, 124.605, 0.12423631577021046, 0.12196353405981064)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (68, 120.0, 178.0, 0.34, 119.66, 0.09714237709196695, 0.09543459216179222)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (69, 115.0, 178.0, 0.305, 114.695, 0.07379806859087085, 0.0724976328448175)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (70, 110.0, 178.0, 0.25, 109.75, 0.0542673872414702, 0.05338999207998632)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (71, 105.0, 178.0, 0.21, 104.79, 0.038459813819435786, 0.03787429985735979)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (72, 100.0, 178.0, 0.185, 99.815, 0.026136284023202547, 0.025742714585188124)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (73, 95.0, 178.0, 0.16, 94.84, 0.016929585111438588, 0.016681461018608592)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (74, 90.0, 178.0, 0.13, 89.87, 0.010378141677296702, 0.010238653438795747)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (75, 85.0, 178.0, 0.115, 84.885, 0.00596967509590026, 0.005889354390994253)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (76, 80.0, 178.0, 0.095, 79.905, 0.0031889059603951377, 0.0031486377908007566)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (77, 75.0, 178.0, 0.08, 74.92, 0.0015620121233042756, 0.0015430637372843311)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (78, 70.0, 178.0, 0.06, 69.94, 0.0006906378383306844, 0.0006834303171897921)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (79, 65.0, 178.0, 0.05, 64.95, 0.0002702444786983748, 0.00026753416525268604)
# (i, K, Sₒ, P, ℬ, cdf(d, K), cdf(d, ℬ)) = (80, 60.0, 178.0, 0.04, 59.96, 9.125234502910521e-5, 9.040199663207024e-5)

# %%
cdf(dIV, 176.75)
# Out:
# 0.48868023058017634

# %% [markdown]
# ## Disclaimer and Risks
# __This content is offered solely for training and informational purposes__. No offer or solicitation to buy or sell securities or derivative products or any investment or trading advice or strategy is made, given, or endorsed by the teaching team.
#
# __Trading involves risk__. Carefully review your financial situation before investing in securities, futures contracts, options, or commodity interests. Past performance, whether actual or indicated by historical tests of strategies, is no guarantee of future performance or success. Trading is generally inappropriate for someone with limited resources, investment or trading experience, or a low-risk tolerance.  Only risk capital that is not required for living expenses.
#
# __You are fully responsible for any investment or trading decisions you make__. You should decide solely based on your financial circumstances, investment or trading objectives, risk tolerance, and liquidity needs.

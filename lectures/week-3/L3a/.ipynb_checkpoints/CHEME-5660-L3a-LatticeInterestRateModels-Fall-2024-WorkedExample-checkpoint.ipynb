# %% [markdown]
# # Example: Understanding the Secrets of the Yield Curve
# Fill me in

# %% [markdown]
# ## Setup
# Set up the computational environment by including the `Include.jl` file. The `Include.jl` file loads external packages, various functions we will use in the exercise, and custom types to model the components of our example problem.
# * For additional information on functions and types used in this material, see the [Julia programming language documentation](https://docs.julialang.org/en/v1/) and the [VLQuantitativeFinancePackage.jl documentation](https://github.com/varnerlab/VLQuantitativeFinancePackage.jl).

# %%
include("Include.jl");
# Out:
#     Updating git-repo `https://github.com/varnerlab/VLQuantitativeFinancePackage.jl.git`
#    Resolving package versions...
#     Updating `~/Desktop/julia_work/CHEME-5660-CourseRepository-Fall-2024/lectures/week-3/L3a/Project.toml`
#   [4119e0bf] ~ VLQuantitativeFinancePackage v1.0.0-DEV `https://github.com/varnerlab/VLQuantitativeFinancePackage.jl.git#main` ⇒ v1.0.0-DEV `https://github.com/varnerlab/VLQuantitativeFinancePackage.jl.git#main`
#     Updating `~/Desktop/julia_work/CHEME-5660-CourseRepository-Fall-2024/lectures/week-3/L3a/Manifest.toml`
#   [4119e0bf] ~ VLQuantitativeFinancePackage v1.0.0-DEV `https://github.com/varnerlab/VLQuantitativeFinancePackage.jl.git#main` ⇒ v1.0.0-DEV `https://github.com/varnerlab/VLQuantitativeFinancePackage.jl.git#main`
# Precompiling project...
#   ✓ VLQuantitativeFinancePackage
#   1 dependency successfully precompiled in 3 seconds. 343 already precompiled.
#   Activating project at `~/Desktop/julia_work/CHEME-5660-CourseRepository-Fall-2024/lectures/week-3/L3a`
#   No Changes to `~/Desktop/julia_work/CHEME-5660-CourseRepository-Fall-2024/lectures/week-3/L3a/Project.toml`
#   No Changes to `~/Desktop/julia_work/CHEME-5660-CourseRepository-Fall-2024/lectures/week-3/L3a/Manifest.toml`
#     Updating registry at `~/.julia/registries/General.toml`
#     Updating git-repo `https://github.com/varnerlab/VLQuantitativeFinancePackage.jl.git`
#   No Changes to `~/Desktop/julia_work/CHEME-5660-CourseRepository-Fall-2024/lectures/week-3/L3a/Project.toml`
#   No Changes to `~/Desktop/julia_work/CHEME-5660-CourseRepository-Fall-2024/lectures/week-3/L3a/Manifest.toml`

# %% [markdown]
# ## Prerequisite: Load the Treasury Rates Dataset
# Fill me in

# %%
discount_model = DiscreteCompoundingModel();

# %% [markdown]
# Fill me in

# %%
par_yield_curve_dataset = CSV.read(joinpath(_PATH_TO_DATA, "UST-Daily-ParYieldCurveRates-08-11-2024.csv"), DataFrame)
# Out:
# 153×14 DataFrame
#  Row │ Date        1 Mo     2 Mo     3 Mo     4 Mo     6 Mo     1 Yr     2 Yr  ⋯
#      │ String15    Float64  Float64  Float64  Float64  Float64  Float64  Float ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ 08/09/2024     5.54     5.4      5.33     5.22     5.02     4.5      4. ⋯
#    2 │ 08/08/2024     5.55     5.42     5.34     5.21     5.01     4.48     4.
#    3 │ 08/07/2024     5.5      5.43     5.34     5.21     4.99     4.45     4.
#    4 │ 08/06/2024     5.5      5.43     5.34     5.18     5.0      4.46     3.
#    5 │ 08/05/2024     5.52     5.43     5.35     5.14     4.91     4.34     3. ⋯
#    6 │ 08/02/2024     5.54     5.43     5.29     5.14     4.88     4.33     3.
#    7 │ 08/01/2024     5.55     5.46     5.37     5.28     5.08     4.62     4.
#    8 │ 07/31/2024     5.49     5.51     5.41     5.32     5.14     4.73     4.
#    9 │ 07/30/2024     5.5      5.5      5.4      5.35     5.16     4.78     4. ⋯
#   10 │ 07/29/2024     5.5      5.51     5.41     5.36     5.18     4.79     4.
#   11 │ 07/26/2024     5.49     5.51     5.38     5.36     5.18     4.79     4.
#   ⋮  │     ⋮          ⋮        ⋮        ⋮        ⋮        ⋮        ⋮        ⋮  ⋱
#  144 │ 01/16/2024     5.54     5.47     5.45     5.37     5.18     4.7      4.
#  145 │ 01/12/2024     5.55     5.47     5.45     5.37     5.16     4.65     4. ⋯
#  146 │ 01/11/2024     5.54     5.47     5.46     5.38     5.22     4.75     4.
#  147 │ 01/10/2024     5.53     5.46     5.46     5.39     5.23     4.82     4.
#  148 │ 01/09/2024     5.53     5.46     5.47     5.38     5.24     4.82     4.
#  149 │ 01/08/2024     5.54     5.48     5.49     5.39     5.24     4.82     4. ⋯
#  150 │ 01/05/2024     5.54     5.48     5.47     5.41     5.24     4.84     4.
#  151 │ 01/04/2024     5.56     5.48     5.48     5.41     5.25     4.85     4.
#  152 │ 01/03/2024     5.54     5.54     5.48     5.41     5.25     4.81     4.
#  153 │ 01/02/2024     5.55     5.54     5.46     5.41     5.24     4.8      4. ⋯
#                                                   7 columns and 132 rows omitted

# %% [markdown]
# ## Task 1: Which yield curve should we be looking at?
# The [United States Treasury](https://home.treasury.gov/policy-issues/financing-the-government/interest-rate-statistics) reports multiple types of interest rate statistics each business day, for example:
# * The [Par Yield Curve Rates](https://home.treasury.gov/policy-issues/financing-the-government/interest-rate-statistics) is based on the closing market bid prices on the most recently auctioned Treasury securities in the over-the-counter market. The par yields are derived from input market prices, which are indicative quotations obtained by the [Federal Reserve Bank of New York at approximately 3:30 PM each business day](https://www.newyorkfed.org/data-and-statistics). For information on how the Treasury’s yield curve is derived, visit [the Treasury Yield Curve Methodology page](https://home.treasury.gov/policy-issues/financing-the-government/interest-rate-statistics/treasury-yield-curve-methodology).
# * The [Daily Treasury Par Real Yield Curve Rates](https://home.treasury.gov/policy-issues/financing-the-government/interest-rate-statistics), which relates the par real yield on a [Treasury Inflation Protected Security (TIPS)](https://www.treasurydirect.gov/marketable-securities/tips/) to its time to maturity, is based on the closing market bid prices on the most recently auctioned TIPS in the over-the-counter market. The par yields are derived from input market prices, which are indicative quotations obtained by the [Federal Reserve Bank of New York at approximately 3:30 PM each business day](https://www.newyorkfed.org/data-and-statistics).
# * The [Daily Treasury Bill Rates](https://home.treasury.gov/policy-issues/financing-the-government/interest-rate-statistics) are indicative closing market bid quotations on the most recently auctioned Treasury Bills in the over-the-counter market as obtained by the [Federal Reserve Bank of New York at approximately 3:30 PM each business day](https://www.newyorkfed.org/data-and-statistics).
#
# Let's explore [the Par Yield Curve Rates](https://home.treasury.gov/policy-issues/financing-the-government/interest-rate-statistics) and try to understand what it is saying.

# %% [markdown]
# ### TODO: Let's explore the Par-yield curve
# __Claim__: When the effective discount rate $\bar{r}$ equals the coupon rate $\bar{c}$, a coupon note (or bond) will trade at it's par value, i.e., $V_{P} = V_{B}$ for all maturities. Let's test this out by constructing [a `MyUSTreasuryCouponSecurityModel` instance](https://varnerlab.github.io/VLQuantitativeFinancePackage.jl/dev/fixed/#VLQuantitativeFinancePackage.MyUSTreasuryCouponSecurityModel) with some typical parameters, and show this claim is valid. Start by setting some typical parameter values:

# %%
Vₚ = 100.0; # par value for the note/bond
r̄ = 0.05;
c̄ = 0.05;
T = 0.25;
λ = 2;

# %% [markdown]
# Then construct [a `MyUSTreasuryCouponSecurityModel` instance](https://varnerlab.github.io/VLQuantitativeFinancePackage.jl/dev/fixed/#VLQuantitativeFinancePackage.MyUSTreasuryCouponSecurityModel) by passing the type we want to build, i.e., [`MyUSTreasuryCouponSecurityModel`](https://varnerlab.github.io/VLQuantitativeFinancePackage.jl/dev/fixed/#VLQuantitativeFinancePackage.MyUSTreasuryCouponSecurityModel) and some typical data for the `par` value, the discount `rate,` the `coupon` rate, the duration `T` (years) and the number of compounding events per year `λ = 2` into a [custom `build(...)` method](https://varnerlab.github.io/VLQuantitativeFinancePackage.jl/dev/fixed/#VLQuantitativeFinancePackage.build-Tuple{Type{MyUSTreasuryCouponSecurityModel},%20NamedTuple}). We save this as the `my_treasury_security_model::MyUSTreasuryCouponSecurityModel` variable.
# * We compute (and populate on the model instance) the `price` and other data fields, such as the cashflow table, for the `my_treasury_security_model::MyUSTreasuryCouponSecurityModel` by passing this model to the `discount_model` using the [built-in Julia pipe `|>` operator](https://docs.julialang.org/en/v1/manual/functions/#Function-composition-and-piping).

# %%
my_treasury_security_model = build(MyUSTreasuryCouponSecurityModel, (
    par = Vₚ,
    rate = r̄,
    coupon = c̄,
    T = T,
    λ = λ
)) |> discount_model;

# %% [markdown]
# Finally, use the [Julia @assert macro](https://docs.julialang.org/en/v1/base/base/#Base.@assert) to verify the claim. If the claim is false, i.e., $V_{P} \neq V_{B}$ when $\bar{r} = \bar{c}$, an [`AssertionError` type is thrown](https://docs.julialang.org/en/v1/base/base/#Core.AssertionError). We use the [Julia `issapprox(...)` method to check for equality](https://docs.julialang.org/en/v1/base/math/#Base.isapprox)

# %%
@assert isapprox(my_treasury_security_model.price, Vₚ, rtol=1e-6) # checks equality to `rtol` value
# Out:
# AssertionError: isapprox(my_treasury_security_model.price, Vₚ, rtol = 1.0e-6)
#
# Stacktrace:
#  [1] top-level scope
#    @ In[14]:1

# %%
my_treasury_security_model.cashflow
# Out:
# Dict{Int64, Float64} with 2 entries:
#   0 => -99.3846
#   1 => 100.0

# %% [markdown]
# ### TODO: Backout Treasury Prices from the Par Yield Curve Data
# Fill me in

# %%
maturity_conversion_dict = Dict{String, Float64}();
basis = 12; # assume a 12-month year
list_of_columns = names(par_yield_curve_dataset)
for column ∈ list_of_columns 
    if (column != "Date")

        # split around the space, and convert to appropriate type
        maturity_fragments = split(column, " "); # split around the space
        duration = maturity_fragments |> first |> string |> x-> parse(Float64, x);
        unit = maturity_fragments |> last;

        # assume: default is years, correct if we have months
        maturity_conversion_dict[column] = duration;
        if (unit == "Mo")
            maturity_conversion_dict[column] = (duration/basis);    
        end
    end
end
maturity_conversion_dict
# Out:
# Dict{String, Float64} with 13 entries:
#   "3 Mo"  => 0.25
#   "20 Yr" => 20.0
#   "30 Yr" => 30.0
#   "6 Mo"  => 0.5
#   "1 Yr"  => 1.0
#   "2 Mo"  => 0.166667
#   "10 Yr" => 10.0
#   "5 Yr"  => 5.0
#   "2 Yr"  => 2.0
#   "4 Mo"  => 0.333333
#   "1 Mo"  => 0.0833333
#   "7 Yr"  => 7.0
#   "3 Yr"  => 3.0

# %%
number_of_dates = nrow(par_yield_curve_dataset);
number_of_columns = names(par_yield_curve_dataset) |> length
reverse_price_array = Array{Float64,2}(undef, number_of_dates, number_of_columns - 1);
for i ∈ 1:number_of_dates
    for j ∈ 2:number_of_columns

        column = list_of_columns[j];
        r̄ = par_yield_curve_dataset[i, column];
        c̄ = r̄
        my_treasury_security_model.T = column |> key -> maturity_conversion_dict[key];        
        reverse_price_array[i,j-1] = my_treasury_security_model |> discount_model |> model -> model.price
    end
end
reverse_price_array
# Out:
# (r̄, column) = (5.54, "1 Mo")
# (r̄, column) = (5.4, "2 Mo")
# (r̄, column) = (5.33, "3 Mo")
# (r̄, column) = (5.22, "4 Mo")
# (r̄, column) = (5.02, "6 Mo")
# (r̄, column) = (4.5, "1 Yr")
# (r̄, column) = (4.05, "2 Yr")
# (r̄, column) = (3.86, "3 Yr")
# (r̄, column) = (3.8, "5 Yr")
# (r̄, column) = (3.85, "7 Yr")
# (r̄, column) = (3.94, "10 Yr")
# (r̄, column) = (4.33, "20 Yr")
# (r̄, column) = (4.23, "30 Yr")
# (r̄, column) = (5.55, "1 Mo")
# (r̄, column) = (5.42, "2 Mo")
# (r̄, column) = (5.34, "3 Mo")
# (r̄, column) = (5.21, "4 Mo")
# (r̄, column) = (5.01, "6 Mo")
# (r̄, column) = (4.48, "1 Yr")
# (r̄, column) = (4.04, "2 Yr")
# (r̄, column) = (3.86, "3 Yr")
# (r̄, column) = (3.83, "5 Yr")
# (r̄, column) = (3.89, "7 Yr")
# (r̄, column) = (3.99, "10 Yr")
# (r̄, column) = (4.38, "20 Yr")
# (r̄, column) = (4.28, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.43, "2 Mo")
# (r̄, column) = (5.34, "3 Mo")
# (r̄, column) = (5.21, "4 Mo")
# (r̄, column) = (4.99, "6 Mo")
# (r̄, column) = (4.45, "1 Yr")
# (r̄, column) = (4.0, "2 Yr")
# (r̄, column) = (3.81, "3 Yr")
# (r̄, column) = (3.79, "5 Yr")
# (r̄, column) = (3.85, "7 Yr")
# (r̄, column) = (3.96, "10 Yr")
# (r̄, column) = (4.35, "20 Yr")
# (r̄, column) = (4.26, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.43, "2 Mo")
# (r̄, column) = (5.34, "3 Mo")
# (r̄, column) = (5.18, "4 Mo")
# (r̄, column) = (5.0, "6 Mo")
# (r̄, column) = (4.46, "1 Yr")
# (r̄, column) = (3.99, "2 Yr")
# (r̄, column) = (3.76, "3 Yr")
# (r̄, column) = (3.73, "5 Yr")
# (r̄, column) = (3.79, "7 Yr")
# (r̄, column) = (3.9, "10 Yr")
# (r̄, column) = (4.28, "20 Yr")
# (r̄, column) = (4.18, "30 Yr")
# (r̄, column) = (5.52, "1 Mo")
# (r̄, column) = (5.43, "2 Mo")
# (r̄, column) = (5.35, "3 Mo")
# (r̄, column) = (5.14, "4 Mo")
# (r̄, column) = (4.91, "6 Mo")
# (r̄, column) = (4.34, "1 Yr")
# (r̄, column) = (3.89, "2 Yr")
# (r̄, column) = (3.71, "3 Yr")
# (r̄, column) = (3.62, "5 Yr")
# (r̄, column) = (3.66, "7 Yr")
# (r̄, column) = (3.78, "10 Yr")
# (r̄, column) = (4.16, "20 Yr")
# (r̄, column) = (4.06, "30 Yr")
# (r̄, column) = (5.54, "1 Mo")
# (r̄, column) = (5.43, "2 Mo")
# (r̄, column) = (5.29, "3 Mo")
# (r̄, column) = (5.14, "4 Mo")
# (r̄, column) = (4.88, "6 Mo")
# (r̄, column) = (4.33, "1 Yr")
# (r̄, column) = (3.88, "2 Yr")
# (r̄, column) = (3.7, "3 Yr")
# (r̄, column) = (3.62, "5 Yr")
# (r̄, column) = (3.68, "7 Yr")
# (r̄, column) = (3.8, "10 Yr")
# (r̄, column) = (4.19, "20 Yr")
# (r̄, column) = (4.11, "30 Yr")
# (r̄, column) = (5.55, "1 Mo")
# (r̄, column) = (5.46, "2 Mo")
# (r̄, column) = (5.37, "3 Mo")
# (r̄, column) = (5.28, "4 Mo")
# (r̄, column) = (5.08, "6 Mo")
# (r̄, column) = (4.62, "1 Yr")
# (r̄, column) = (4.16, "2 Yr")
# (r̄, column) = (3.96, "3 Yr")
# (r̄, column) = (3.84, "5 Yr")
# (r̄, column) = (3.89, "7 Yr")
# (r̄, column) = (3.99, "10 Yr")
# (r̄, column) = (4.35, "20 Yr")
# (r̄, column) = (4.27, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.41, "3 Mo")
# (r̄, column) = (5.32, "4 Mo")
# (r̄, column) = (5.14, "6 Mo")
# (r̄, column) = (4.73, "1 Yr")
# (r̄, column) = (4.29, "2 Yr")
# (r̄, column) = (4.1, "3 Yr")
# (r̄, column) = (3.97, "5 Yr")
# (r̄, column) = (4.0, "7 Yr")
# (r̄, column) = (4.09, "10 Yr")
# (r̄, column) = (4.44, "20 Yr")
# (r̄, column) = (4.35, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.4, "3 Mo")
# (r̄, column) = (5.35, "4 Mo")
# (r̄, column) = (5.16, "6 Mo")
# (r̄, column) = (4.78, "1 Yr")
# (r̄, column) = (4.35, "2 Yr")
# (r̄, column) = (4.16, "3 Yr")
# (r̄, column) = (4.03, "5 Yr")
# (r̄, column) = (4.06, "7 Yr")
# (r̄, column) = (4.15, "10 Yr")
# (r̄, column) = (4.5, "20 Yr")
# (r̄, column) = (4.4, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.41, "3 Mo")
# (r̄, column) = (5.36, "4 Mo")
# (r̄, column) = (5.18, "6 Mo")
# (r̄, column) = (4.79, "1 Yr")
# (r̄, column) = (4.36, "2 Yr")
# (r̄, column) = (4.19, "3 Yr")
# (r̄, column) = (4.05, "5 Yr")
# (r̄, column) = (4.08, "7 Yr")
# (r̄, column) = (4.17, "10 Yr")
# (r̄, column) = (4.51, "20 Yr")
# (r̄, column) = (4.42, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.38, "3 Mo")
# (r̄, column) = (5.36, "4 Mo")
# (r̄, column) = (5.18, "6 Mo")
# (r̄, column) = (4.79, "1 Yr")
# (r̄, column) = (4.36, "2 Yr")
# (r̄, column) = (4.2, "3 Yr")
# (r̄, column) = (4.06, "5 Yr")
# (r̄, column) = (4.1, "7 Yr")
# (r̄, column) = (4.2, "10 Yr")
# (r̄, column) = (4.53, "20 Yr")
# (r̄, column) = (4.45, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.52, "2 Mo")
# (r̄, column) = (5.39, "3 Mo")
# (r̄, column) = (5.37, "4 Mo")
# (r̄, column) = (5.19, "6 Mo")
# (r̄, column) = (4.83, "1 Yr")
# (r̄, column) = (4.41, "2 Yr")
# (r̄, column) = (4.26, "3 Yr")
# (r̄, column) = (4.13, "5 Yr")
# (r̄, column) = (4.18, "7 Yr")
# (r̄, column) = (4.27, "10 Yr")
# (r̄, column) = (4.59, "20 Yr")
# (r̄, column) = (4.5, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.4, "3 Mo")
# (r̄, column) = (5.37, "4 Mo")
# (r̄, column) = (5.19, "6 Mo")
# (r̄, column) = (4.82, "1 Yr")
# (r̄, column) = (4.37, "2 Yr")
# (r̄, column) = (4.24, "3 Yr")
# (r̄, column) = (4.12, "5 Yr")
# (r̄, column) = (4.2, "7 Yr")
# (r̄, column) = (4.28, "10 Yr")
# (r̄, column) = (4.62, "20 Yr")
# (r̄, column) = (4.54, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.41, "3 Mo")
# (r̄, column) = (5.38, "4 Mo")
# (r̄, column) = (5.22, "6 Mo")
# (r̄, column) = (4.85, "1 Yr")
# (r̄, column) = (4.4, "2 Yr")
# (r̄, column) = (4.26, "3 Yr")
# (r̄, column) = (4.15, "5 Yr")
# (r̄, column) = (4.18, "7 Yr")
# (r̄, column) = (4.25, "10 Yr")
# (r̄, column) = (4.56, "20 Yr")
# (r̄, column) = (4.48, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.43, "3 Mo")
# (r̄, column) = (5.39, "4 Mo")
# (r̄, column) = (5.24, "6 Mo")
# (r̄, column) = (4.88, "1 Yr")
# (r̄, column) = (4.5, "2 Yr")
# (r̄, column) = (4.29, "3 Yr")
# (r̄, column) = (4.17, "5 Yr")
# (r̄, column) = (4.2, "7 Yr")
# (r̄, column) = (4.26, "10 Yr")
# (r̄, column) = (4.57, "20 Yr")
# (r̄, column) = (4.48, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.52, "2 Mo")
# (r̄, column) = (5.43, "3 Mo")
# (r̄, column) = (5.39, "4 Mo")
# (r̄, column) = (5.24, "6 Mo")
# (r̄, column) = (4.87, "1 Yr")
# (r̄, column) = (4.49, "2 Yr")
# (r̄, column) = (4.28, "3 Yr")
# (r̄, column) = (4.16, "5 Yr")
# (r̄, column) = (4.18, "7 Yr")
# (r̄, column) = (4.25, "10 Yr")
# (r̄, column) = (4.55, "20 Yr")
# (r̄, column) = (4.45, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.52, "2 Mo")
# (r̄, column) = (5.43, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.23, "6 Mo")
# (r̄, column) = (4.86, "1 Yr")
# (r̄, column) = (4.46, "2 Yr")
# (r̄, column) = (4.24, "3 Yr")
# (r̄, column) = (4.11, "5 Yr")
# (r̄, column) = (4.14, "7 Yr")
# (r̄, column) = (4.2, "10 Yr")
# (r̄, column) = (4.51, "20 Yr")
# (r̄, column) = (4.41, "30 Yr")
# (r̄, column) = (5.47, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.43, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.23, "6 Mo")
# (r̄, column) = (4.85, "1 Yr")
# (r̄, column) = (4.42, "2 Yr")
# (r̄, column) = (4.19, "3 Yr")
# (r̄, column) = (4.07, "5 Yr")
# (r̄, column) = (4.09, "7 Yr")
# (r̄, column) = (4.16, "10 Yr")
# (r̄, column) = (4.46, "20 Yr")
# (r̄, column) = (4.37, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.43, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.23, "6 Mo")
# (r̄, column) = (4.85, "1 Yr")
# (r̄, column) = (4.43, "2 Yr")
# (r̄, column) = (4.21, "3 Yr")
# (r̄, column) = (4.09, "5 Yr")
# (r̄, column) = (4.11, "7 Yr")
# (r̄, column) = (4.17, "10 Yr")
# (r̄, column) = (4.48, "20 Yr")
# (r̄, column) = (4.38, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.43, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.23, "6 Mo")
# (r̄, column) = (4.85, "1 Yr")
# (r̄, column) = (4.44, "2 Yr")
# (r̄, column) = (4.23, "3 Yr")
# (r̄, column) = (4.13, "5 Yr")
# (r̄, column) = (4.16, "7 Yr")
# (r̄, column) = (4.23, "10 Yr")
# (r̄, column) = (4.56, "20 Yr")
# (r̄, column) = (4.46, "30 Yr")
# (r̄, column) = (5.47, "1 Mo")
# (r̄, column) = (5.52, "2 Mo")
# (r̄, column) = (5.43, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.23, "6 Mo")
# (r̄, column) = (4.87, "1 Yr")
# (r̄, column) = (4.45, "2 Yr")
# (r̄, column) = (4.22, "3 Yr")
# (r̄, column) = (4.1, "5 Yr")
# (r̄, column) = (4.13, "7 Yr")
# (r̄, column) = (4.18, "10 Yr")
# (r̄, column) = (4.5, "20 Yr")
# (r̄, column) = (4.39, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.53, "2 Mo")
# (r̄, column) = (5.44, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.25, "6 Mo")
# (r̄, column) = (4.91, "1 Yr")
# (r̄, column) = (4.5, "2 Yr")
# (r̄, column) = (4.26, "3 Yr")
# (r̄, column) = (4.13, "5 Yr")
# (r̄, column) = (4.15, "7 Yr")
# (r̄, column) = (4.2, "10 Yr")
# (r̄, column) = (4.51, "20 Yr")
# (r̄, column) = (4.41, "30 Yr")
# (r̄, column) = (5.46, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.46, "4 Mo")
# (r̄, column) = (5.33, "6 Mo")
# (r̄, column) = (5.01, "1 Yr")
# (r̄, column) = (4.62, "2 Yr")
# (r̄, column) = (4.38, "3 Yr")
# (r̄, column) = (4.24, "5 Yr")
# (r̄, column) = (4.24, "7 Yr")
# (r̄, column) = (4.28, "10 Yr")
# (r̄, column) = (4.58, "20 Yr")
# (r̄, column) = (4.47, "30 Yr")
# (r̄, column) = (5.45, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.46, "4 Mo")
# (r̄, column) = (5.34, "6 Mo")
# (r̄, column) = (5.02, "1 Yr")
# (r̄, column) = (4.62, "2 Yr")
# (r̄, column) = (4.37, "3 Yr")
# (r̄, column) = (4.24, "5 Yr")
# (r̄, column) = (4.25, "7 Yr")
# (r̄, column) = (4.3, "10 Yr")
# (r̄, column) = (4.59, "20 Yr")
# (r̄, column) = (4.49, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.53, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.46, "4 Mo")
# (r̄, column) = (5.33, "6 Mo")
# (r̄, column) = (4.99, "1 Yr")
# (r̄, column) = (4.62, "2 Yr")
# (r̄, column) = (4.4, "3 Yr")
# (r̄, column) = (4.23, "5 Yr")
# (r̄, column) = (4.23, "7 Yr")
# (r̄, column) = (4.28, "10 Yr")
# (r̄, column) = (4.57, "20 Yr")
# (r̄, column) = (4.46, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.53, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.46, "4 Mo")
# (r̄, column) = (5.34, "6 Mo")
# (r̄, column) = (4.98, "1 Yr")
# (r̄, column) = (4.6, "2 Yr")
# (r̄, column) = (4.39, "3 Yr")
# (r̄, column) = (4.22, "5 Yr")
# (r̄, column) = (4.23, "7 Yr")
# (r̄, column) = (4.28, "10 Yr")
# (r̄, column) = (4.57, "20 Yr")
# (r̄, column) = (4.47, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.54, "2 Mo")
# (r̄, column) = (5.47, "3 Mo")
# (r̄, column) = (5.47, "4 Mo")
# (r̄, column) = (5.36, "6 Mo")
# (r̄, column) = (5.04, "1 Yr")
# (r̄, column) = (4.71, "2 Yr")
# (r̄, column) = (4.48, "3 Yr")
# (r̄, column) = (4.33, "5 Yr")
# (r̄, column) = (4.33, "7 Yr")
# (r̄, column) = (4.36, "10 Yr")
# (r̄, column) = (4.64, "20 Yr")
# (r̄, column) = (4.53, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.47, "3 Mo")
# (r̄, column) = (5.44, "4 Mo")
# (r̄, column) = (5.36, "6 Mo")
# (r̄, column) = (5.07, "1 Yr")
# (r̄, column) = (4.74, "2 Yr")
# (r̄, column) = (4.54, "3 Yr")
# (r̄, column) = (4.39, "5 Yr")
# (r̄, column) = (4.4, "7 Yr")
# (r̄, column) = (4.43, "10 Yr")
# (r̄, column) = (4.71, "20 Yr")
# (r̄, column) = (4.6, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.47, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.37, "6 Mo")
# (r̄, column) = (5.1, "1 Yr")
# (r̄, column) = (4.77, "2 Yr")
# (r̄, column) = (4.58, "3 Yr")
# (r̄, column) = (4.44, "5 Yr")
# (r̄, column) = (4.45, "7 Yr")
# (r̄, column) = (4.48, "10 Yr")
# (r̄, column) = (4.76, "20 Yr")
# (r̄, column) = (4.64, "30 Yr")
# (r̄, column) = (5.47, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.48, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.33, "6 Mo")
# (r̄, column) = (5.09, "1 Yr")
# (r̄, column) = (4.71, "2 Yr")
# (r̄, column) = (4.52, "3 Yr")
# (r̄, column) = (4.33, "5 Yr")
# (r̄, column) = (4.33, "7 Yr")
# (r̄, column) = (4.36, "10 Yr")
# (r̄, column) = (4.61, "20 Yr")
# (r̄, column) = (4.51, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.46, "2 Mo")
# (r̄, column) = (5.49, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.35, "6 Mo")
# (r̄, column) = (5.1, "1 Yr")
# (r̄, column) = (4.7, "2 Yr")
# (r̄, column) = (4.49, "3 Yr")
# (r̄, column) = (4.29, "5 Yr")
# (r̄, column) = (4.27, "7 Yr")
# (r̄, column) = (4.29, "10 Yr")
# (r̄, column) = (4.53, "20 Yr")
# (r̄, column) = (4.43, "30 Yr")
# (r̄, column) = (5.44, "1 Mo")
# (r̄, column) = (5.46, "2 Mo")
# (r̄, column) = (5.5, "3 Mo")
# (r̄, column) = (5.46, "4 Mo")
# (r̄, column) = (5.36, "6 Mo")
# (r̄, column) = (5.13, "1 Yr")
# (r̄, column) = (4.71, "2 Yr")
# (r̄, column) = (4.53, "3 Yr")
# (r̄, column) = (4.32, "5 Yr")
# (r̄, column) = (4.32, "7 Yr")
# (r̄, column) = (4.32, "10 Yr")
# (r̄, column) = (4.55, "20 Yr")
# (r̄, column) = (4.45, "30 Yr")
# (r̄, column) = (5.43, "1 Mo")
# (r̄, column) = (5.46, "2 Mo")
# (r̄, column) = (5.49, "3 Mo")
# (r̄, column) = (5.44, "4 Mo")
# (r̄, column) = (5.37, "6 Mo")
# (r̄, column) = (5.1, "1 Yr")
# (r̄, column) = (4.65, "2 Yr")
# (r̄, column) = (4.45, "3 Yr")
# (r̄, column) = (4.25, "5 Yr")
# (r̄, column) = (4.23, "7 Yr")
# (r̄, column) = (4.23, "10 Yr")
# (r̄, column) = (4.46, "20 Yr")
# (r̄, column) = (4.36, "30 Yr")
# (r̄, column) = (5.42, "1 Mo")
# (r̄, column) = (5.46, "2 Mo")
# (r̄, column) = (5.5, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.37, "6 Mo")
# (r̄, column) = (5.1, "1 Yr")
# (r̄, column) = (4.71, "2 Yr")
# (r̄, column) = (4.46, "3 Yr")
# (r̄, column) = (4.27, "5 Yr")
# (r̄, column) = (4.25, "7 Yr")
# (r̄, column) = (4.25, "10 Yr")
# (r̄, column) = (4.48, "20 Yr")
# (r̄, column) = (4.38, "30 Yr")
# (r̄, column) = (5.42, "1 Mo")
# (r̄, column) = (5.46, "2 Mo")
# (r̄, column) = (5.49, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.36, "6 Mo")
# (r̄, column) = (5.1, "1 Yr")
# (r̄, column) = (4.7, "2 Yr")
# (r̄, column) = (4.45, "3 Yr")
# (r̄, column) = (4.26, "5 Yr")
# (r̄, column) = (4.25, "7 Yr")
# (r̄, column) = (4.25, "10 Yr")
# (r̄, column) = (4.49, "20 Yr")
# (r̄, column) = (4.39, "30 Yr")
# (r̄, column) = (5.42, "1 Mo")
# (r̄, column) = (5.46, "2 Mo")
# (r̄, column) = (5.5, "3 Mo")
# (r̄, column) = (5.46, "4 Mo")
# (r̄, column) = (5.37, "6 Mo")
# (r̄, column) = (5.1, "1 Yr")
# (r̄, column) = (4.7, "2 Yr")
# (r̄, column) = (4.45, "3 Yr")
# (r̄, column) = (4.26, "5 Yr")
# (r̄, column) = (4.25, "7 Yr")
# (r̄, column) = (4.25, "10 Yr")
# (r̄, column) = (4.49, "20 Yr")
# (r̄, column) = (4.39, "30 Yr")
# (r̄, column) = (5.4, "1 Mo")
# (r̄, column) = (5.46, "2 Mo")
# (r̄, column) = (5.5, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.37, "6 Mo")
# (r̄, column) = (5.09, "1 Yr")
# (r̄, column) = (4.69, "2 Yr")
# (r̄, column) = (4.43, "3 Yr")
# (r̄, column) = (4.24, "5 Yr")
# (r̄, column) = (4.22, "7 Yr")
# (r̄, column) = (4.22, "10 Yr")
# (r̄, column) = (4.47, "20 Yr")
# (r̄, column) = (4.36, "30 Yr")
# (r̄, column) = (5.45, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.52, "3 Mo")
# (r̄, column) = (5.46, "4 Mo")
# (r̄, column) = (5.39, "6 Mo")
# (r̄, column) = (5.11, "1 Yr")
# (r̄, column) = (4.75, "2 Yr")
# (r̄, column) = (4.5, "3 Yr")
# (r̄, column) = (4.3, "5 Yr")
# (r̄, column) = (4.28, "7 Yr")
# (r̄, column) = (4.28, "10 Yr")
# (r̄, column) = (4.52, "20 Yr")
# (r̄, column) = (4.4, "30 Yr")
# (r̄, column) = (5.47, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.51, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.36, "6 Mo")
# (r̄, column) = (5.07, "1 Yr")
# (r̄, column) = (4.67, "2 Yr")
# (r̄, column) = (4.41, "3 Yr")
# (r̄, column) = (4.22, "5 Yr")
# (r̄, column) = (4.2, "7 Yr")
# (r̄, column) = (4.2, "10 Yr")
# (r̄, column) = (4.46, "20 Yr")
# (r̄, column) = (4.34, "30 Yr")
# (r̄, column) = (5.47, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.51, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.36, "6 Mo")
# (r̄, column) = (5.07, "1 Yr")
# (r̄, column) = (4.68, "2 Yr")
# (r̄, column) = (4.42, "3 Yr")
# (r̄, column) = (4.24, "5 Yr")
# (r̄, column) = (4.23, "7 Yr")
# (r̄, column) = (4.24, "10 Yr")
# (r̄, column) = (4.5, "20 Yr")
# (r̄, column) = (4.4, "30 Yr")
# (r̄, column) = (5.47, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.51, "3 Mo")
# (r̄, column) = (5.47, "4 Mo")
# (r̄, column) = (5.38, "6 Mo")
# (r̄, column) = (5.13, "1 Yr")
# (r̄, column) = (4.75, "2 Yr")
# (r̄, column) = (4.48, "3 Yr")
# (r̄, column) = (4.32, "5 Yr")
# (r̄, column) = (4.31, "7 Yr")
# (r̄, column) = (4.31, "10 Yr")
# (r̄, column) = (4.56, "20 Yr")
# (r̄, column) = (4.47, "30 Yr")
# (r̄, column) = (5.46, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.52, "3 Mo")
# (r̄, column) = (5.46, "4 Mo")
# (r̄, column) = (5.39, "6 Mo")
# (r̄, column) = (5.17, "1 Yr")
# (r̄, column) = (4.81, "2 Yr")
# (r̄, column) = (4.57, "3 Yr")
# (r̄, column) = (4.41, "5 Yr")
# (r̄, column) = (4.4, "7 Yr")
# (r̄, column) = (4.39, "10 Yr")
# (r̄, column) = (4.62, "20 Yr")
# (r̄, column) = (4.53, "30 Yr")
# (r̄, column) = (5.47, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.52, "3 Mo")
# (r̄, column) = (5.46, "4 Mo")
# (r̄, column) = (5.4, "6 Mo")
# (r̄, column) = (5.16, "1 Yr")
# (r̄, column) = (4.87, "2 Yr")
# (r̄, column) = (4.62, "3 Yr")
# (r̄, column) = (4.48, "5 Yr")
# (r̄, column) = (4.47, "7 Yr")
# (r̄, column) = (4.47, "10 Yr")
# (r̄, column) = (4.68, "20 Yr")
# (r̄, column) = (4.59, "30 Yr")
# (r̄, column) = (5.47, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.52, "3 Mo")
# (r̄, column) = (5.47, "4 Mo")
# (r̄, column) = (5.4, "6 Mo")
# (r̄, column) = (5.17, "1 Yr")
# (r̄, column) = (4.87, "2 Yr")
# (r̄, column) = (4.65, "3 Yr")
# (r̄, column) = (4.46, "5 Yr")
# (r̄, column) = (4.45, "7 Yr")
# (r̄, column) = (4.43, "10 Yr")
# (r̄, column) = (4.64, "20 Yr")
# (r̄, column) = (4.55, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.51, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.36, "6 Mo")
# (r̄, column) = (5.08, "1 Yr")
# (r̄, column) = (4.72, "2 Yr")
# (r̄, column) = (4.49, "3 Yr")
# (r̄, column) = (4.29, "5 Yr")
# (r̄, column) = (4.28, "7 Yr")
# (r̄, column) = (4.28, "10 Yr")
# (r̄, column) = (4.51, "20 Yr")
# (r̄, column) = (4.43, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.51, "3 Mo")
# (r̄, column) = (5.46, "4 Mo")
# (r̄, column) = (5.37, "6 Mo")
# (r̄, column) = (5.08, "1 Yr")
# (r̄, column) = (4.72, "2 Yr")
# (r̄, column) = (4.5, "3 Yr")
# (r̄, column) = (4.31, "5 Yr")
# (r̄, column) = (4.29, "7 Yr")
# (r̄, column) = (4.29, "10 Yr")
# (r̄, column) = (4.52, "20 Yr")
# (r̄, column) = (4.44, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.52, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.38, "6 Mo")
# (r̄, column) = (5.11, "1 Yr")
# (r̄, column) = (4.77, "2 Yr")
# (r̄, column) = (4.55, "3 Yr")
# (r̄, column) = (4.35, "5 Yr")
# (r̄, column) = (4.33, "7 Yr")
# (r̄, column) = (4.33, "10 Yr")
# (r̄, column) = (4.56, "20 Yr")
# (r̄, column) = (4.48, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.49, "2 Mo")
# (r̄, column) = (5.52, "3 Mo")
# (r̄, column) = (5.46, "4 Mo")
# (r̄, column) = (5.39, "6 Mo")
# (r̄, column) = (5.14, "1 Yr")
# (r̄, column) = (4.82, "2 Yr")
# (r̄, column) = (4.62, "3 Yr")
# (r̄, column) = (4.42, "5 Yr")
# (r̄, column) = (4.41, "7 Yr")
# (r̄, column) = (4.41, "10 Yr")
# (r̄, column) = (4.63, "20 Yr")
# (r̄, column) = (4.55, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.46, "4 Mo")
# (r̄, column) = (5.42, "6 Mo")
# (r̄, column) = (5.18, "1 Yr")
# (r̄, column) = (4.89, "2 Yr")
# (r̄, column) = (4.69, "3 Yr")
# (r̄, column) = (4.52, "5 Yr")
# (r̄, column) = (4.52, "7 Yr")
# (r̄, column) = (4.51, "10 Yr")
# (r̄, column) = (4.73, "20 Yr")
# (r̄, column) = (4.65, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.48, "4 Mo")
# (r̄, column) = (5.42, "6 Mo")
# (r̄, column) = (5.19, "1 Yr")
# (r̄, column) = (4.92, "2 Yr")
# (r̄, column) = (4.74, "3 Yr")
# (r̄, column) = (4.57, "5 Yr")
# (r̄, column) = (4.57, "7 Yr")
# (r̄, column) = (4.55, "10 Yr")
# (r̄, column) = (4.76, "20 Yr")
# (r̄, column) = (4.69, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.47, "4 Mo")
# (r̄, column) = (5.43, "6 Mo")
# (r̄, column) = (5.22, "1 Yr")
# (r̄, column) = (4.96, "2 Yr")
# (r̄, column) = (4.79, "3 Yr")
# (r̄, column) = (4.63, "5 Yr")
# (r̄, column) = (4.63, "7 Yr")
# (r̄, column) = (4.61, "10 Yr")
# (r̄, column) = (4.82, "20 Yr")
# (r̄, column) = (4.74, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.51, "4 Mo")
# (r̄, column) = (5.43, "6 Mo")
# (r̄, column) = (5.21, "1 Yr")
# (r̄, column) = (4.94, "2 Yr")
# (r̄, column) = (4.75, "3 Yr")
# (r̄, column) = (4.56, "5 Yr")
# (r̄, column) = (4.56, "7 Yr")
# (r̄, column) = (4.54, "10 Yr")
# (r̄, column) = (4.74, "20 Yr")
# (r̄, column) = (4.66, "30 Yr")
# (r̄, column) = (5.56, "1 Mo")
# (r̄, column) = (5.53, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.51, "4 Mo")
# (r̄, column) = (5.44, "6 Mo")
# (r̄, column) = (5.21, "1 Yr")
# (r̄, column) = (4.93, "2 Yr")
# (r̄, column) = (4.71, "3 Yr")
# (r̄, column) = (4.53, "5 Yr")
# (r̄, column) = (4.49, "7 Yr")
# (r̄, column) = (4.46, "10 Yr")
# (r̄, column) = (4.65, "20 Yr")
# (r̄, column) = (4.57, "30 Yr")
# (r̄, column) = (5.51, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.51, "4 Mo")
# (r̄, column) = (5.44, "6 Mo")
# (r̄, column) = (5.2, "1 Yr")
# (r̄, column) = (4.91, "2 Yr")
# (r̄, column) = (4.71, "3 Yr")
# (r̄, column) = (4.52, "5 Yr")
# (r̄, column) = (4.5, "7 Yr")
# (r̄, column) = (4.47, "10 Yr")
# (r̄, column) = (4.67, "20 Yr")
# (r̄, column) = (4.58, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.5, "4 Mo")
# (r̄, column) = (5.43, "6 Mo")
# (r̄, column) = (5.16, "1 Yr")
# (r̄, column) = (4.86, "2 Yr")
# (r̄, column) = (4.64, "3 Yr")
# (r̄, column) = (4.47, "5 Yr")
# (r̄, column) = (4.44, "7 Yr")
# (r̄, column) = (4.43, "10 Yr")
# (r̄, column) = (4.63, "20 Yr")
# (r̄, column) = (4.55, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.51, "4 Mo")
# (r̄, column) = (5.42, "6 Mo")
# (r̄, column) = (5.14, "1 Yr")
# (r̄, column) = (4.82, "2 Yr")
# (r̄, column) = (4.61, "3 Yr")
# (r̄, column) = (4.43, "5 Yr")
# (r̄, column) = (4.42, "7 Yr")
# (r̄, column) = (4.41, "10 Yr")
# (r̄, column) = (4.65, "20 Yr")
# (r̄, column) = (4.55, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.51, "4 Mo")
# (r̄, column) = (5.43, "6 Mo")
# (r̄, column) = (5.15, "1 Yr")
# (r̄, column) = (4.82, "2 Yr")
# (r̄, column) = (4.62, "3 Yr")
# (r̄, column) = (4.46, "5 Yr")
# (r̄, column) = (4.44, "7 Yr")
# (r̄, column) = (4.44, "10 Yr")
# (r̄, column) = (4.68, "20 Yr")
# (r̄, column) = (4.58, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.5, "4 Mo")
# (r̄, column) = (5.41, "6 Mo")
# (r̄, column) = (5.14, "1 Yr")
# (r̄, column) = (4.83, "2 Yr")
# (r̄, column) = (4.6, "3 Yr")
# (r̄, column) = (4.44, "5 Yr")
# (r̄, column) = (4.43, "7 Yr")
# (r̄, column) = (4.42, "10 Yr")
# (r̄, column) = (4.66, "20 Yr")
# (r̄, column) = (4.56, "30 Yr")
# (r̄, column) = (5.51, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.53, "4 Mo")
# (r̄, column) = (5.41, "6 Mo")
# (r̄, column) = (5.13, "1 Yr")
# (r̄, column) = (4.78, "2 Yr")
# (r̄, column) = (4.58, "3 Yr")
# (r̄, column) = (4.4, "5 Yr")
# (r̄, column) = (4.39, "7 Yr")
# (r̄, column) = (4.38, "10 Yr")
# (r̄, column) = (4.62, "20 Yr")
# (r̄, column) = (4.52, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.46, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.5, "4 Mo")
# (r̄, column) = (5.4, "6 Mo")
# (r̄, column) = (5.1, "1 Yr")
# (r̄, column) = (4.73, "2 Yr")
# (r̄, column) = (4.51, "3 Yr")
# (r̄, column) = (4.35, "5 Yr")
# (r̄, column) = (4.35, "7 Yr")
# (r̄, column) = (4.36, "10 Yr")
# (r̄, column) = (4.61, "20 Yr")
# (r̄, column) = (4.52, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.44, "3 Mo")
# (r̄, column) = (5.51, "4 Mo")
# (r̄, column) = (5.43, "6 Mo")
# (r̄, column) = (5.16, "1 Yr")
# (r̄, column) = (4.81, "2 Yr")
# (r̄, column) = (4.62, "3 Yr")
# (r̄, column) = (4.46, "5 Yr")
# (r̄, column) = (4.45, "7 Yr")
# (r̄, column) = (4.45, "10 Yr")
# (r̄, column) = (4.69, "20 Yr")
# (r̄, column) = (4.59, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.51, "4 Mo")
# (r̄, column) = (5.43, "6 Mo")
# (r̄, column) = (5.16, "1 Yr")
# (r̄, column) = (4.85, "2 Yr")
# (r̄, column) = (4.66, "3 Yr")
# (r̄, column) = (4.5, "5 Yr")
# (r̄, column) = (4.49, "7 Yr")
# (r̄, column) = (4.48, "10 Yr")
# (r̄, column) = (4.72, "20 Yr")
# (r̄, column) = (4.63, "30 Yr")
# (r̄, column) = (5.51, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.47, "3 Mo")
# (r̄, column) = (5.51, "4 Mo")
# (r̄, column) = (5.43, "6 Mo")
# (r̄, column) = (5.17, "1 Yr")
# (r̄, column) = (4.87, "2 Yr")
# (r̄, column) = (4.65, "3 Yr")
# (r̄, column) = (4.52, "5 Yr")
# (r̄, column) = (4.51, "7 Yr")
# (r̄, column) = (4.5, "10 Yr")
# (r̄, column) = (4.74, "20 Yr")
# (r̄, column) = (4.64, "30 Yr")
# (r̄, column) = (5.51, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.5, "4 Mo")
# (r̄, column) = (5.41, "6 Mo")
# (r̄, column) = (5.12, "1 Yr")
# (r̄, column) = (4.8, "2 Yr")
# (r̄, column) = (4.6, "3 Yr")
# (r̄, column) = (4.47, "5 Yr")
# (r̄, column) = (4.46, "7 Yr")
# (r̄, column) = (4.45, "10 Yr")
# (r̄, column) = (4.7, "20 Yr")
# (r̄, column) = (4.6, "30 Yr")
# (r̄, column) = (5.51, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.5, "4 Mo")
# (r̄, column) = (5.41, "6 Mo")
# (r̄, column) = (5.13, "1 Yr")
# (r̄, column) = (4.84, "2 Yr")
# (r̄, column) = (4.63, "3 Yr")
# (r̄, column) = (4.5, "5 Yr")
# (r̄, column) = (4.49, "7 Yr")
# (r̄, column) = (4.48, "10 Yr")
# (r̄, column) = (4.73, "20 Yr")
# (r̄, column) = (4.64, "30 Yr")
# (r̄, column) = (5.51, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.51, "4 Mo")
# (r̄, column) = (5.41, "6 Mo")
# (r̄, column) = (5.13, "1 Yr")
# (r̄, column) = (4.82, "2 Yr")
# (r̄, column) = (4.6, "3 Yr")
# (r̄, column) = (4.48, "5 Yr")
# (r̄, column) = (4.47, "7 Yr")
# (r̄, column) = (4.47, "10 Yr")
# (r̄, column) = (4.7, "20 Yr")
# (r̄, column) = (4.61, "30 Yr")
# (r̄, column) = (5.51, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.5, "4 Mo")
# (r̄, column) = (5.42, "6 Mo")
# (r̄, column) = (5.12, "1 Yr")
# (r̄, column) = (4.82, "2 Yr")
# (r̄, column) = (4.64, "3 Yr")
# (r̄, column) = (4.48, "5 Yr")
# (r̄, column) = (4.48, "7 Yr")
# (r̄, column) = (4.49, "10 Yr")
# (r̄, column) = (4.73, "20 Yr")
# (r̄, column) = (4.64, "30 Yr")
# (r̄, column) = (5.51, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.5, "4 Mo")
# (r̄, column) = (5.41, "6 Mo")
# (r̄, column) = (5.12, "1 Yr")
# (r̄, column) = (4.81, "2 Yr")
# (r̄, column) = (4.63, "3 Yr")
# (r̄, column) = (4.48, "5 Yr")
# (r̄, column) = (4.49, "7 Yr")
# (r̄, column) = (4.5, "10 Yr")
# (r̄, column) = (4.75, "20 Yr")
# (r̄, column) = (4.66, "30 Yr")
# (r̄, column) = (5.51, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.5, "4 Mo")
# (r̄, column) = (5.42, "6 Mo")
# (r̄, column) = (5.16, "1 Yr")
# (r̄, column) = (4.87, "2 Yr")
# (r̄, column) = (4.71, "3 Yr")
# (r̄, column) = (4.57, "5 Yr")
# (r̄, column) = (4.57, "7 Yr")
# (r̄, column) = (4.58, "10 Yr")
# (r̄, column) = (4.82, "20 Yr")
# (r̄, column) = (4.72, "30 Yr")
# (r̄, column) = (5.47, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.51, "4 Mo")
# (r̄, column) = (5.43, "6 Mo")
# (r̄, column) = (5.21, "1 Yr")
# (r̄, column) = (4.96, "2 Yr")
# (r̄, column) = (4.79, "3 Yr")
# (r̄, column) = (4.64, "5 Yr")
# (r̄, column) = (4.64, "7 Yr")
# (r̄, column) = (4.63, "10 Yr")
# (r̄, column) = (4.85, "20 Yr")
# (r̄, column) = (4.74, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.44, "6 Mo")
# (r̄, column) = (5.25, "1 Yr")
# (r̄, column) = (5.04, "2 Yr")
# (r̄, column) = (4.87, "3 Yr")
# (r̄, column) = (4.72, "5 Yr")
# (r̄, column) = (4.71, "7 Yr")
# (r̄, column) = (4.69, "10 Yr")
# (r̄, column) = (4.9, "20 Yr")
# (r̄, column) = (4.79, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.43, "6 Mo")
# (r̄, column) = (5.2, "1 Yr")
# (r̄, column) = (4.97, "2 Yr")
# (r̄, column) = (4.8, "3 Yr")
# (r̄, column) = (4.65, "5 Yr")
# (r̄, column) = (4.64, "7 Yr")
# (r̄, column) = (4.63, "10 Yr")
# (r̄, column) = (4.86, "20 Yr")
# (r̄, column) = (4.75, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.4, "6 Mo")
# (r̄, column) = (5.21, "1 Yr")
# (r̄, column) = (4.96, "2 Yr")
# (r̄, column) = (4.84, "3 Yr")
# (r̄, column) = (4.68, "5 Yr")
# (r̄, column) = (4.68, "7 Yr")
# (r̄, column) = (4.67, "10 Yr")
# (r̄, column) = (4.89, "20 Yr")
# (r̄, column) = (4.78, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.47, "3 Mo")
# (r̄, column) = (5.46, "4 Mo")
# (r̄, column) = (5.41, "6 Mo")
# (r̄, column) = (5.21, "1 Yr")
# (r̄, column) = (4.96, "2 Yr")
# (r̄, column) = (4.85, "3 Yr")
# (r̄, column) = (4.7, "5 Yr")
# (r̄, column) = (4.71, "7 Yr")
# (r̄, column) = (4.7, "10 Yr")
# (r̄, column) = (4.93, "20 Yr")
# (r̄, column) = (4.82, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.44, "4 Mo")
# (r̄, column) = (5.4, "6 Mo")
# (r̄, column) = (5.17, "1 Yr")
# (r̄, column) = (4.89, "2 Yr")
# (r̄, column) = (4.78, "3 Yr")
# (r̄, column) = (4.64, "5 Yr")
# (r̄, column) = (4.66, "7 Yr")
# (r̄, column) = (4.65, "10 Yr")
# (r̄, column) = (4.88, "20 Yr")
# (r̄, column) = (4.78, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.44, "4 Mo")
# (r̄, column) = (5.39, "6 Mo")
# (r̄, column) = (5.14, "1 Yr")
# (r̄, column) = (4.86, "2 Yr")
# (r̄, column) = (4.76, "3 Yr")
# (r̄, column) = (4.63, "5 Yr")
# (r̄, column) = (4.62, "7 Yr")
# (r̄, column) = (4.61, "10 Yr")
# (r̄, column) = (4.84, "20 Yr")
# (r̄, column) = (4.73, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.42, "3 Mo")
# (r̄, column) = (5.44, "4 Mo")
# (r̄, column) = (5.39, "6 Mo")
# (r̄, column) = (5.16, "1 Yr")
# (r̄, column) = (4.97, "2 Yr")
# (r̄, column) = (4.81, "3 Yr")
# (r̄, column) = (4.66, "5 Yr")
# (r̄, column) = (4.65, "7 Yr")
# (r̄, column) = (4.62, "10 Yr")
# (r̄, column) = (4.84, "20 Yr")
# (r̄, column) = (4.72, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.44, "4 Mo")
# (r̄, column) = (5.39, "6 Mo")
# (r̄, column) = (5.17, "1 Yr")
# (r̄, column) = (4.97, "2 Yr")
# (r̄, column) = (4.81, "3 Yr")
# (r̄, column) = (4.66, "5 Yr")
# (r̄, column) = (4.65, "7 Yr")
# (r̄, column) = (4.62, "10 Yr")
# (r̄, column) = (4.83, "20 Yr")
# (r̄, column) = (4.72, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.52, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.44, "4 Mo")
# (r̄, column) = (5.39, "6 Mo")
# (r̄, column) = (5.18, "1 Yr")
# (r̄, column) = (4.98, "2 Yr")
# (r̄, column) = (4.83, "3 Yr")
# (r̄, column) = (4.68, "5 Yr")
# (r̄, column) = (4.67, "7 Yr")
# (r̄, column) = (4.64, "10 Yr")
# (r̄, column) = (4.85, "20 Yr")
# (r̄, column) = (4.74, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.49, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.44, "4 Mo")
# (r̄, column) = (5.38, "6 Mo")
# (r̄, column) = (5.16, "1 Yr")
# (r̄, column) = (4.93, "2 Yr")
# (r̄, column) = (4.77, "3 Yr")
# (r̄, column) = (4.62, "5 Yr")
# (r̄, column) = (4.61, "7 Yr")
# (r̄, column) = (4.59, "10 Yr")
# (r̄, column) = (4.81, "20 Yr")
# (r̄, column) = (4.71, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.44, "4 Mo")
# (r̄, column) = (5.39, "6 Mo")
# (r̄, column) = (5.18, "1 Yr")
# (r̄, column) = (4.97, "2 Yr")
# (r̄, column) = (4.83, "3 Yr")
# (r̄, column) = (4.69, "5 Yr")
# (r̄, column) = (4.69, "7 Yr")
# (r̄, column) = (4.67, "10 Yr")
# (r̄, column) = (4.88, "20 Yr")
# (r̄, column) = (4.77, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.44, "4 Mo")
# (r̄, column) = (5.38, "6 Mo")
# (r̄, column) = (5.16, "1 Yr")
# (r̄, column) = (4.93, "2 Yr")
# (r̄, column) = (4.78, "3 Yr")
# (r̄, column) = (4.65, "5 Yr")
# (r̄, column) = (4.65, "7 Yr")
# (r̄, column) = (4.63, "10 Yr")
# (r̄, column) = (4.85, "20 Yr")
# (r̄, column) = (4.74, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.42, "4 Mo")
# (r̄, column) = (5.36, "6 Mo")
# (r̄, column) = (5.13, "1 Yr")
# (r̄, column) = (4.88, "2 Yr")
# (r̄, column) = (4.7, "3 Yr")
# (r̄, column) = (4.54, "5 Yr")
# (r̄, column) = (4.53, "7 Yr")
# (r̄, column) = (4.5, "10 Yr")
# (r̄, column) = (4.73, "20 Yr")
# (r̄, column) = (4.61, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.44, "4 Mo")
# (r̄, column) = (5.38, "6 Mo")
# (r̄, column) = (5.17, "1 Yr")
# (r̄, column) = (4.93, "2 Yr")
# (r̄, column) = (4.77, "3 Yr")
# (r̄, column) = (4.61, "5 Yr")
# (r̄, column) = (4.6, "7 Yr")
# (r̄, column) = (4.56, "10 Yr")
# (r̄, column) = (4.77, "20 Yr")
# (r̄, column) = (4.65, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.44, "4 Mo")
# (r̄, column) = (5.4, "6 Mo")
# (r̄, column) = (5.19, "1 Yr")
# (r̄, column) = (4.97, "2 Yr")
# (r̄, column) = (4.77, "3 Yr")
# (r̄, column) = (4.61, "5 Yr")
# (r̄, column) = (4.59, "7 Yr")
# (r̄, column) = (4.55, "10 Yr")
# (r̄, column) = (4.76, "20 Yr")
# (r̄, column) = (4.64, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.49, "2 Mo")
# (r̄, column) = (5.43, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.34, "6 Mo")
# (r̄, column) = (5.03, "1 Yr")
# (r̄, column) = (4.74, "2 Yr")
# (r̄, column) = (4.52, "3 Yr")
# (r̄, column) = (4.37, "5 Yr")
# (r̄, column) = (4.38, "7 Yr")
# (r̄, column) = (4.36, "10 Yr")
# (r̄, column) = (4.6, "20 Yr")
# (r̄, column) = (4.5, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.49, "2 Mo")
# (r̄, column) = (5.43, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.35, "6 Mo")
# (r̄, column) = (5.07, "1 Yr")
# (r̄, column) = (4.78, "2 Yr")
# (r̄, column) = (4.6, "3 Yr")
# (r̄, column) = (4.43, "5 Yr")
# (r̄, column) = (4.43, "7 Yr")
# (r̄, column) = (4.42, "10 Yr")
# (r̄, column) = (4.65, "20 Yr")
# (r̄, column) = (4.55, "30 Yr")
# (r̄, column) = (5.47, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.43, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.34, "6 Mo")
# (r̄, column) = (5.05, "1 Yr")
# (r̄, column) = (4.73, "2 Yr")
# (r̄, column) = (4.54, "3 Yr")
# (r̄, column) = (4.38, "5 Yr")
# (r̄, column) = (4.39, "7 Yr")
# (r̄, column) = (4.39, "10 Yr")
# (r̄, column) = (4.65, "20 Yr")
# (r̄, column) = (4.54, "30 Yr")
# (r̄, column) = (5.47, "1 Mo")
# (r̄, column) = (5.49, "2 Mo")
# (r̄, column) = (5.41, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.32, "6 Mo")
# (r̄, column) = (5.0, "1 Yr")
# (r̄, column) = (4.65, "2 Yr")
# (r̄, column) = (4.46, "3 Yr")
# (r̄, column) = (4.3, "5 Yr")
# (r̄, column) = (4.31, "7 Yr")
# (r̄, column) = (4.31, "10 Yr")
# (r̄, column) = (4.57, "20 Yr")
# (r̄, column) = (4.47, "30 Yr")
# (r̄, column) = (5.47, "1 Mo")
# (r̄, column) = (5.44, "2 Mo")
# (r̄, column) = (5.42, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.33, "6 Mo")
# (r̄, column) = (5.03, "1 Yr")
# (r̄, column) = (4.68, "2 Yr")
# (r̄, column) = (4.48, "3 Yr")
# (r̄, column) = (4.34, "5 Yr")
# (r̄, column) = (4.36, "7 Yr")
# (r̄, column) = (4.36, "10 Yr")
# (r̄, column) = (4.61, "20 Yr")
# (r̄, column) = (4.51, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.45, "2 Mo")
# (r̄, column) = (5.42, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.34, "6 Mo")
# (r̄, column) = (5.05, "1 Yr")
# (r̄, column) = (4.7, "2 Yr")
# (r̄, column) = (4.51, "3 Yr")
# (r̄, column) = (4.35, "5 Yr")
# (r̄, column) = (4.37, "7 Yr")
# (r̄, column) = (4.36, "10 Yr")
# (r̄, column) = (4.61, "20 Yr")
# (r̄, column) = (4.51, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.44, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.36, "6 Mo")
# (r̄, column) = (5.06, "1 Yr")
# (r̄, column) = (4.72, "2 Yr")
# (r̄, column) = (4.51, "3 Yr")
# (r̄, column) = (4.34, "5 Yr")
# (r̄, column) = (4.33, "7 Yr")
# (r̄, column) = (4.33, "10 Yr")
# (r̄, column) = (4.58, "20 Yr")
# (r̄, column) = (4.47, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.42, "4 Mo")
# (r̄, column) = (5.38, "6 Mo")
# (r̄, column) = (5.03, "1 Yr")
# (r̄, column) = (4.59, "2 Yr")
# (r̄, column) = (4.4, "3 Yr")
# (r̄, column) = (4.21, "5 Yr")
# (r̄, column) = (4.2, "7 Yr")
# (r̄, column) = (4.2, "10 Yr")
# (r̄, column) = (4.45, "20 Yr")
# (r̄, column) = (4.34, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.36, "6 Mo")
# (r̄, column) = (4.99, "1 Yr")
# (r̄, column) = (4.54, "2 Yr")
# (r̄, column) = (4.36, "3 Yr")
# (r̄, column) = (4.18, "5 Yr")
# (r̄, column) = (4.18, "7 Yr")
# (r̄, column) = (4.2, "10 Yr")
# (r̄, column) = (4.45, "20 Yr")
# (r̄, column) = (4.36, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.36, "6 Mo")
# (r̄, column) = (5.0, "1 Yr")
# (r̄, column) = (4.56, "2 Yr")
# (r̄, column) = (4.38, "3 Yr")
# (r̄, column) = (4.22, "5 Yr")
# (r̄, column) = (4.23, "7 Yr")
# (r̄, column) = (4.24, "10 Yr")
# (r̄, column) = (4.49, "20 Yr")
# (r̄, column) = (4.4, "30 Yr")
# (r̄, column) = (5.51, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.36, "6 Mo")
# (r̄, column) = (5.0, "1 Yr")
# (r̄, column) = (4.54, "2 Yr")
# (r̄, column) = (4.39, "3 Yr")
# (r̄, column) = (4.23, "5 Yr")
# (r̄, column) = (4.25, "7 Yr")
# (r̄, column) = (4.25, "10 Yr")
# (r̄, column) = (4.51, "20 Yr")
# (r̄, column) = (4.42, "30 Yr")
# (r̄, column) = (5.51, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.34, "6 Mo")
# (r̄, column) = (4.98, "1 Yr")
# (r̄, column) = (4.59, "2 Yr")
# (r̄, column) = (4.36, "3 Yr")
# (r̄, column) = (4.2, "5 Yr")
# (r̄, column) = (4.22, "7 Yr")
# (r̄, column) = (4.22, "10 Yr")
# (r̄, column) = (4.47, "20 Yr")
# (r̄, column) = (4.39, "30 Yr")
# (r̄, column) = (5.51, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.48, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.36, "6 Mo")
# (r̄, column) = (5.01, "1 Yr")
# (r̄, column) = (4.62, "2 Yr")
# (r̄, column) = (4.42, "3 Yr")
# (r̄, column) = (4.26, "5 Yr")
# (r̄, column) = (4.28, "7 Yr")
# (r̄, column) = (4.27, "10 Yr")
# (r̄, column) = (4.53, "20 Yr")
# (r̄, column) = (4.44, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.47, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.36, "6 Mo")
# (r̄, column) = (5.01, "1 Yr")
# (r̄, column) = (4.59, "2 Yr")
# (r̄, column) = (4.41, "3 Yr")
# (r̄, column) = (4.25, "5 Yr")
# (r̄, column) = (4.28, "7 Yr")
# (r̄, column) = (4.27, "10 Yr")
# (r̄, column) = (4.53, "20 Yr")
# (r̄, column) = (4.45, "30 Yr")
# (r̄, column) = (5.52, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.48, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.39, "6 Mo")
# (r̄, column) = (5.06, "1 Yr")
# (r̄, column) = (4.68, "2 Yr")
# (r̄, column) = (4.47, "3 Yr")
# (r̄, column) = (4.31, "5 Yr")
# (r̄, column) = (4.31, "7 Yr")
# (r̄, column) = (4.3, "10 Yr")
# (r̄, column) = (4.54, "20 Yr")
# (r̄, column) = (4.44, "30 Yr")
# (r̄, column) = (5.52, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.48, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.39, "6 Mo")
# (r̄, column) = (5.06, "1 Yr")
# (r̄, column) = (4.73, "2 Yr")
# (r̄, column) = (4.52, "3 Yr")
# (r̄, column) = (4.36, "5 Yr")
# (r̄, column) = (4.35, "7 Yr")
# (r̄, column) = (4.34, "10 Yr")
# (r̄, column) = (4.57, "20 Yr")
# (r̄, column) = (4.46, "30 Yr")
# (r̄, column) = (5.52, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.48, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.38, "6 Mo")
# (r̄, column) = (5.05, "1 Yr")
# (r̄, column) = (4.72, "2 Yr")
# (r̄, column) = (4.51, "3 Yr")
# (r̄, column) = (4.33, "5 Yr")
# (r̄, column) = (4.33, "7 Yr")
# (r̄, column) = (4.31, "10 Yr")
# (r̄, column) = (4.55, "20 Yr")
# (r̄, column) = (4.43, "30 Yr")
# (r̄, column) = (5.52, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.48, "3 Mo")
# (r̄, column) = (5.42, "4 Mo")
# (r̄, column) = (5.38, "6 Mo")
# (r̄, column) = (5.04, "1 Yr")
# (r̄, column) = (4.68, "2 Yr")
# (r̄, column) = (4.46, "3 Yr")
# (r̄, column) = (4.29, "5 Yr")
# (r̄, column) = (4.3, "7 Yr")
# (r̄, column) = (4.29, "10 Yr")
# (r̄, column) = (4.54, "20 Yr")
# (r̄, column) = (4.44, "30 Yr")
# (r̄, column) = (5.52, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.48, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.37, "6 Mo")
# (r̄, column) = (5.01, "1 Yr")
# (r̄, column) = (4.61, "2 Yr")
# (r̄, column) = (4.37, "3 Yr")
# (r̄, column) = (4.19, "5 Yr")
# (r̄, column) = (4.2, "7 Yr")
# (r̄, column) = (4.19, "10 Yr")
# (r̄, column) = (4.45, "20 Yr")
# (r̄, column) = (4.35, "30 Yr")
# (r̄, column) = (5.52, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.48, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.37, "6 Mo")
# (r̄, column) = (5.0, "1 Yr")
# (r̄, column) = (4.58, "2 Yr")
# (r̄, column) = (4.33, "3 Yr")
# (r̄, column) = (4.15, "5 Yr")
# (r̄, column) = (4.16, "7 Yr")
# (r̄, column) = (4.16, "10 Yr")
# (r̄, column) = (4.42, "20 Yr")
# (r̄, column) = (4.31, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.48, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.35, "6 Mo")
# (r̄, column) = (4.95, "1 Yr")
# (r̄, column) = (4.51, "2 Yr")
# (r̄, column) = (4.26, "3 Yr")
# (r̄, column) = (4.08, "5 Yr")
# (r̄, column) = (4.09, "7 Yr")
# (r̄, column) = (4.1, "10 Yr")
# (r̄, column) = (4.36, "20 Yr")
# (r̄, column) = (4.26, "30 Yr")
# (r̄, column) = (5.51, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.34, "6 Mo")
# (r̄, column) = (4.92, "1 Yr")
# (r̄, column) = (4.48, "2 Yr")
# (r̄, column) = (4.25, "3 Yr")
# (r̄, column) = (4.06, "5 Yr")
# (r̄, column) = (4.08, "7 Yr")
# (r̄, column) = (4.09, "10 Yr")
# (r̄, column) = (4.36, "20 Yr")
# (r̄, column) = (4.26, "30 Yr")
# (r̄, column) = (5.51, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.47, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.34, "6 Mo")
# (r̄, column) = (4.93, "1 Yr")
# (r̄, column) = (4.5, "2 Yr")
# (r̄, column) = (4.28, "3 Yr")
# (r̄, column) = (4.07, "5 Yr")
# (r̄, column) = (4.09, "7 Yr")
# (r̄, column) = (4.09, "10 Yr")
# (r̄, column) = (4.35, "20 Yr")
# (r̄, column) = (4.25, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.47, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.35, "6 Mo")
# (r̄, column) = (4.95, "1 Yr")
# (r̄, column) = (4.55, "2 Yr")
# (r̄, column) = (4.32, "3 Yr")
# (r̄, column) = (4.12, "5 Yr")
# (r̄, column) = (4.12, "7 Yr")
# (r̄, column) = (4.11, "10 Yr")
# (r̄, column) = (4.36, "20 Yr")
# (r̄, column) = (4.24, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.47, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.35, "6 Mo")
# (r̄, column) = (4.94, "1 Yr")
# (r̄, column) = (4.54, "2 Yr")
# (r̄, column) = (4.32, "3 Yr")
# (r̄, column) = (4.13, "5 Yr")
# (r̄, column) = (4.15, "7 Yr")
# (r̄, column) = (4.13, "10 Yr")
# (r̄, column) = (4.39, "20 Yr")
# (r̄, column) = (4.27, "30 Yr")
# (r̄, column) = (5.51, "1 Mo")
# (r̄, column) = (5.49, "2 Mo")
# (r̄, column) = (5.48, "3 Mo")
# (r̄, column) = (5.42, "4 Mo")
# (r̄, column) = (5.37, "6 Mo")
# (r̄, column) = (4.98, "1 Yr")
# (r̄, column) = (4.61, "2 Yr")
# (r̄, column) = (4.39, "3 Yr")
# (r̄, column) = (4.21, "5 Yr")
# (r̄, column) = (4.23, "7 Yr")
# (r̄, column) = (4.22, "10 Yr")
# (r̄, column) = (4.48, "20 Yr")
# (r̄, column) = (4.36, "30 Yr")
# (r̄, column) = (5.54, "1 Mo")
# (r̄, column) = (5.49, "2 Mo")
# (r̄, column) = (5.42, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.27, "6 Mo")
# (r̄, column) = (4.94, "1 Yr")
# (r̄, column) = (4.54, "2 Yr")
# (r̄, column) = (4.32, "3 Yr")
# (r̄, column) = (4.17, "5 Yr")
# (r̄, column) = (4.2, "7 Yr")
# (r̄, column) = (4.19, "10 Yr")
# (r̄, column) = (4.46, "20 Yr")
# (r̄, column) = (4.33, "30 Yr")
# (r̄, column) = (5.53, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.43, "4 Mo")
# (r̄, column) = (5.3, "6 Mo")
# (r̄, column) = (5.01, "1 Yr")
# (r̄, column) = (4.64, "2 Yr")
# (r̄, column) = (4.43, "3 Yr")
# (r̄, column) = (4.26, "5 Yr")
# (r̄, column) = (4.28, "7 Yr")
# (r̄, column) = (4.25, "10 Yr")
# (r̄, column) = (4.51, "20 Yr")
# (r̄, column) = (4.38, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.43, "4 Mo")
# (r̄, column) = (5.31, "6 Mo")
# (r̄, column) = (5.0, "1 Yr")
# (r̄, column) = (4.64, "2 Yr")
# (r̄, column) = (4.44, "3 Yr")
# (r̄, column) = (4.26, "5 Yr")
# (r̄, column) = (4.28, "7 Yr")
# (r̄, column) = (4.27, "10 Yr")
# (r̄, column) = (4.53, "20 Yr")
# (r̄, column) = (4.4, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.52, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.47, "4 Mo")
# (r̄, column) = (5.33, "6 Mo")
# (r̄, column) = (5.03, "1 Yr")
# (r̄, column) = (4.7, "2 Yr")
# (r̄, column) = (4.5, "3 Yr")
# (r̄, column) = (4.32, "5 Yr")
# (r̄, column) = (4.34, "7 Yr")
# (r̄, column) = (4.31, "10 Yr")
# (r̄, column) = (4.57, "20 Yr")
# (r̄, column) = (4.44, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.52, "2 Mo")
# (r̄, column) = (5.47, "3 Mo")
# (r̄, column) = (5.47, "4 Mo")
# (r̄, column) = (5.34, "6 Mo")
# (r̄, column) = (5.03, "1 Yr")
# (r̄, column) = (4.69, "2 Yr")
# (r̄, column) = (4.48, "3 Yr")
# (r̄, column) = (4.29, "5 Yr")
# (r̄, column) = (4.32, "7 Yr")
# (r̄, column) = (4.28, "10 Yr")
# (r̄, column) = (4.53, "20 Yr")
# (r̄, column) = (4.4, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.46, "4 Mo")
# (r̄, column) = (5.32, "6 Mo")
# (r̄, column) = (5.0, "1 Yr")
# (r̄, column) = (4.67, "2 Yr")
# (r̄, column) = (4.45, "3 Yr")
# (r̄, column) = (4.28, "5 Yr")
# (r̄, column) = (4.28, "7 Yr")
# (r̄, column) = (4.26, "10 Yr")
# (r̄, column) = (4.51, "20 Yr")
# (r̄, column) = (4.37, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.32, "6 Mo")
# (r̄, column) = (5.02, "1 Yr")
# (r̄, column) = (4.69, "2 Yr")
# (r̄, column) = (4.49, "3 Yr")
# (r̄, column) = (4.33, "5 Yr")
# (r̄, column) = (4.35, "7 Yr")
# (r̄, column) = (4.33, "10 Yr")
# (r̄, column) = (4.58, "20 Yr")
# (r̄, column) = (4.47, "30 Yr")
# (r̄, column) = (5.5, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.44, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.32, "6 Mo")
# (r̄, column) = (4.98, "1 Yr")
# (r̄, column) = (4.64, "2 Yr")
# (r̄, column) = (4.43, "3 Yr")
# (r̄, column) = (4.3, "5 Yr")
# (r̄, column) = (4.33, "7 Yr")
# (r̄, column) = (4.32, "10 Yr")
# (r̄, column) = (4.59, "20 Yr")
# (r̄, column) = (4.49, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.49, "2 Mo")
# (r̄, column) = (5.44, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.32, "6 Mo")
# (r̄, column) = (4.97, "1 Yr")
# (r̄, column) = (4.59, "2 Yr")
# (r̄, column) = (4.38, "3 Yr")
# (r̄, column) = (4.25, "5 Yr")
# (r̄, column) = (4.28, "7 Yr")
# (r̄, column) = (4.27, "10 Yr")
# (r̄, column) = (4.56, "20 Yr")
# (r̄, column) = (4.44, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.44, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.31, "6 Mo")
# (r̄, column) = (4.98, "1 Yr")
# (r̄, column) = (4.64, "2 Yr")
# (r̄, column) = (4.43, "3 Yr")
# (r̄, column) = (4.29, "5 Yr")
# (r̄, column) = (4.31, "7 Yr")
# (r̄, column) = (4.3, "10 Yr")
# (r̄, column) = (4.58, "20 Yr")
# (r̄, column) = (4.45, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.43, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.3, "6 Mo")
# (r̄, column) = (4.93, "1 Yr")
# (r̄, column) = (4.56, "2 Yr")
# (r̄, column) = (4.36, "3 Yr")
# (r̄, column) = (4.22, "5 Yr")
# (r̄, column) = (4.25, "7 Yr")
# (r̄, column) = (4.24, "10 Yr")
# (r̄, column) = (4.54, "20 Yr")
# (r̄, column) = (4.42, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.43, "3 Mo")
# (r̄, column) = (5.45, "4 Mo")
# (r̄, column) = (5.31, "6 Mo")
# (r̄, column) = (4.94, "1 Yr")
# (r̄, column) = (4.56, "2 Yr")
# (r̄, column) = (4.38, "3 Yr")
# (r̄, column) = (4.25, "5 Yr")
# (r̄, column) = (4.27, "7 Yr")
# (r̄, column) = (4.27, "10 Yr")
# (r̄, column) = (4.57, "20 Yr")
# (r̄, column) = (4.45, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.52, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.46, "4 Mo")
# (r̄, column) = (5.32, "6 Mo")
# (r̄, column) = (4.99, "1 Yr")
# (r̄, column) = (4.64, "2 Yr")
# (r̄, column) = (4.44, "3 Yr")
# (r̄, column) = (4.31, "5 Yr")
# (r̄, column) = (4.33, "7 Yr")
# (r̄, column) = (4.31, "10 Yr")
# (r̄, column) = (4.59, "20 Yr")
# (r̄, column) = (4.46, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.43, "3 Mo")
# (r̄, column) = (5.43, "4 Mo")
# (r̄, column) = (5.27, "6 Mo")
# (r̄, column) = (4.87, "1 Yr")
# (r̄, column) = (4.46, "2 Yr")
# (r̄, column) = (4.25, "3 Yr")
# (r̄, column) = (4.13, "5 Yr")
# (r̄, column) = (4.16, "7 Yr")
# (r̄, column) = (4.17, "10 Yr")
# (r̄, column) = (4.48, "20 Yr")
# (r̄, column) = (4.37, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.44, "3 Mo")
# (r̄, column) = (5.43, "4 Mo")
# (r̄, column) = (5.26, "6 Mo")
# (r̄, column) = (4.86, "1 Yr")
# (r̄, column) = (4.48, "2 Yr")
# (r̄, column) = (4.25, "3 Yr")
# (r̄, column) = (4.14, "5 Yr")
# (r̄, column) = (4.17, "7 Yr")
# (r̄, column) = (4.17, "10 Yr")
# (r̄, column) = (4.48, "20 Yr")
# (r̄, column) = (4.37, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.44, "3 Mo")
# (r̄, column) = (5.42, "4 Mo")
# (r̄, column) = (5.24, "6 Mo")
# (r̄, column) = (4.83, "1 Yr")
# (r̄, column) = (4.46, "2 Yr")
# (r̄, column) = (4.22, "3 Yr")
# (r̄, column) = (4.12, "5 Yr")
# (r̄, column) = (4.15, "7 Yr")
# (r̄, column) = (4.15, "10 Yr")
# (r̄, column) = (4.47, "20 Yr")
# (r̄, column) = (4.36, "30 Yr")
# (r̄, column) = (5.47, "1 Mo")
# (r̄, column) = (5.49, "2 Mo")
# (r̄, column) = (5.43, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.23, "6 Mo")
# (r̄, column) = (4.83, "1 Yr")
# (r̄, column) = (4.41, "2 Yr")
# (r̄, column) = (4.16, "3 Yr")
# (r̄, column) = (4.06, "5 Yr")
# (r̄, column) = (4.09, "7 Yr")
# (r̄, column) = (4.09, "10 Yr")
# (r̄, column) = (4.41, "20 Yr")
# (r̄, column) = (4.31, "30 Yr")
# (r̄, column) = (5.48, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.44, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.23, "6 Mo")
# (r̄, column) = (4.82, "1 Yr")
# (r̄, column) = (4.39, "2 Yr")
# (r̄, column) = (4.14, "3 Yr")
# (r̄, column) = (4.03, "5 Yr")
# (r̄, column) = (4.07, "7 Yr")
# (r̄, column) = (4.09, "10 Yr")
# (r̄, column) = (4.39, "20 Yr")
# (r̄, column) = (4.29, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.5, "2 Mo")
# (r̄, column) = (5.42, "3 Mo")
# (r̄, column) = (5.42, "4 Mo")
# (r̄, column) = (5.25, "6 Mo")
# (r̄, column) = (4.87, "1 Yr")
# (r̄, column) = (4.46, "2 Yr")
# (r̄, column) = (4.27, "3 Yr")
# (r̄, column) = (4.13, "5 Yr")
# (r̄, column) = (4.16, "7 Yr")
# (r̄, column) = (4.17, "10 Yr")
# (r̄, column) = (4.46, "20 Yr")
# (r̄, column) = (4.35, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.43, "3 Mo")
# (r̄, column) = (5.42, "4 Mo")
# (r̄, column) = (5.22, "6 Mo")
# (r̄, column) = (4.81, "1 Yr")
# (r̄, column) = (4.36, "2 Yr")
# (r̄, column) = (4.14, "3 Yr")
# (r̄, column) = (3.99, "5 Yr")
# (r̄, column) = (4.02, "7 Yr")
# (r̄, column) = (4.03, "10 Yr")
# (r̄, column) = (4.33, "20 Yr")
# (r̄, column) = (4.22, "30 Yr")
# (r̄, column) = (5.49, "1 Mo")
# (r̄, column) = (5.51, "2 Mo")
# (r̄, column) = (5.42, "3 Mo")
# (r̄, column) = (5.38, "4 Mo")
# (r̄, column) = (5.15, "6 Mo")
# (r̄, column) = (4.68, "1 Yr")
# (r̄, column) = (4.2, "2 Yr")
# (r̄, column) = (3.96, "3 Yr")
# (r̄, column) = (3.8, "5 Yr")
# (r̄, column) = (3.83, "7 Yr")
# (r̄, column) = (3.87, "10 Yr")
# (r̄, column) = (4.21, "20 Yr")
# (r̄, column) = (4.1, "30 Yr")
# (r̄, column) = (5.53, "1 Mo")
# (r̄, column) = (5.46, "2 Mo")
# (r̄, column) = (5.42, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.18, "6 Mo")
# (r̄, column) = (4.73, "1 Yr")
# (r̄, column) = (4.27, "2 Yr")
# (r̄, column) = (4.05, "3 Yr")
# (r̄, column) = (3.91, "5 Yr")
# (r̄, column) = (3.95, "7 Yr")
# (r̄, column) = (3.99, "10 Yr")
# (r̄, column) = (4.34, "20 Yr")
# (r̄, column) = (4.22, "30 Yr")
# (r̄, column) = (5.53, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.42, "3 Mo")
# (r̄, column) = (5.38, "4 Mo")
# (r̄, column) = (5.19, "6 Mo")
# (r̄, column) = (4.8, "1 Yr")
# (r̄, column) = (4.36, "2 Yr")
# (r̄, column) = (4.14, "3 Yr")
# (r̄, column) = (4.0, "5 Yr")
# (r̄, column) = (4.03, "7 Yr")
# (r̄, column) = (4.06, "10 Yr")
# (r̄, column) = (4.4, "20 Yr")
# (r̄, column) = (4.28, "30 Yr")
# (r̄, column) = (5.53, "1 Mo")
# (r̄, column) = (5.46, "2 Mo")
# (r̄, column) = (5.42, "3 Mo")
# (r̄, column) = (5.37, "4 Mo")
# (r̄, column) = (5.19, "6 Mo")
# (r̄, column) = (4.76, "1 Yr")
# (r̄, column) = (4.29, "2 Yr")
# (r̄, column) = (4.1, "3 Yr")
# (r̄, column) = (3.97, "5 Yr")
# (r̄, column) = (4.02, "7 Yr")
# (r̄, column) = (4.08, "10 Yr")
# (r̄, column) = (4.42, "20 Yr")
# (r̄, column) = (4.31, "30 Yr")
# (r̄, column) = (5.54, "1 Mo")
# (r̄, column) = (5.45, "2 Mo")
# (r̄, column) = (5.44, "3 Mo")
# (r̄, column) = (5.39, "4 Mo")
# (r̄, column) = (5.19, "6 Mo")
# (r̄, column) = (4.78, "1 Yr")
# (r̄, column) = (4.34, "2 Yr")
# (r̄, column) = (4.15, "3 Yr")
# (r̄, column) = (4.04, "5 Yr")
# (r̄, column) = (4.1, "7 Yr")
# (r̄, column) = (4.15, "10 Yr")
# (r̄, column) = (4.49, "20 Yr")
# (r̄, column) = (4.38, "30 Yr")
# (r̄, column) = (5.54, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.44, "3 Mo")
# (r̄, column) = (5.39, "4 Mo")
# (r̄, column) = (5.19, "6 Mo")
# (r̄, column) = (4.76, "1 Yr")
# (r̄, column) = (4.28, "2 Yr")
# (r̄, column) = (4.12, "3 Yr")
# (r̄, column) = (4.01, "5 Yr")
# (r̄, column) = (4.07, "7 Yr")
# (r̄, column) = (4.14, "10 Yr")
# (r̄, column) = (4.49, "20 Yr")
# (r̄, column) = (4.38, "30 Yr")
# (r̄, column) = (5.52, "1 Mo")
# (r̄, column) = (5.44, "2 Mo")
# (r̄, column) = (5.44, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.22, "6 Mo")
# (r̄, column) = (4.83, "1 Yr")
# (r̄, column) = (4.34, "2 Yr")
# (r̄, column) = (4.19, "3 Yr")
# (r̄, column) = (4.06, "5 Yr")
# (r̄, column) = (4.14, "7 Yr")
# (r̄, column) = (4.18, "10 Yr")
# (r̄, column) = (4.52, "20 Yr")
# (r̄, column) = (4.41, "30 Yr")
# (r̄, column) = (5.53, "1 Mo")
# (r̄, column) = (5.46, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.38, "4 Mo")
# (r̄, column) = (5.21, "6 Mo")
# (r̄, column) = (4.81, "1 Yr")
# (r̄, column) = (4.31, "2 Yr")
# (r̄, column) = (4.16, "3 Yr")
# (r̄, column) = (4.06, "5 Yr")
# (r̄, column) = (4.11, "7 Yr")
# (r̄, column) = (4.14, "10 Yr")
# (r̄, column) = (4.48, "20 Yr")
# (r̄, column) = (4.38, "30 Yr")
# (r̄, column) = (5.53, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.39, "4 Mo")
# (r̄, column) = (5.22, "6 Mo")
# (r̄, column) = (4.83, "1 Yr")
# (r̄, column) = (4.37, "2 Yr")
# (r̄, column) = (4.14, "3 Yr")
# (r̄, column) = (4.03, "5 Yr")
# (r̄, column) = (4.07, "7 Yr")
# (r̄, column) = (4.11, "10 Yr")
# (r̄, column) = (4.44, "20 Yr")
# (r̄, column) = (4.32, "30 Yr")
# (r̄, column) = (5.54, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.39, "4 Mo")
# (r̄, column) = (5.21, "6 Mo")
# (r̄, column) = (4.84, "1 Yr")
# (r̄, column) = (4.39, "2 Yr")
# (r̄, column) = (4.18, "3 Yr")
# (r̄, column) = (4.08, "5 Yr")
# (r̄, column) = (4.12, "7 Yr")
# (r̄, column) = (4.15, "10 Yr")
# (r̄, column) = (4.47, "20 Yr")
# (r̄, column) = (4.36, "30 Yr")
# (r̄, column) = (5.53, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.39, "4 Mo")
# (r̄, column) = (5.2, "6 Mo")
# (r̄, column) = (4.8, "1 Yr")
# (r̄, column) = (4.34, "2 Yr")
# (r̄, column) = (4.13, "3 Yr")
# (r̄, column) = (4.04, "5 Yr")
# (r̄, column) = (4.1, "7 Yr")
# (r̄, column) = (4.14, "10 Yr")
# (r̄, column) = (4.48, "20 Yr")
# (r̄, column) = (4.37, "30 Yr")
# (r̄, column) = (5.54, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.47, "3 Mo")
# (r̄, column) = (5.4, "4 Mo")
# (r̄, column) = (5.2, "6 Mo")
# (r̄, column) = (4.8, "1 Yr")
# (r̄, column) = (4.34, "2 Yr")
# (r̄, column) = (4.12, "3 Yr")
# (r̄, column) = (4.02, "5 Yr")
# (r̄, column) = (4.07, "7 Yr")
# (r̄, column) = (4.1, "10 Yr")
# (r̄, column) = (4.42, "20 Yr")
# (r̄, column) = (4.31, "30 Yr")
# (r̄, column) = (5.54, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.37, "4 Mo")
# (r̄, column) = (5.18, "6 Mo")
# (r̄, column) = (4.7, "1 Yr")
# (r̄, column) = (4.22, "2 Yr")
# (r̄, column) = (4.02, "3 Yr")
# (r̄, column) = (3.95, "5 Yr")
# (r̄, column) = (4.01, "7 Yr")
# (r̄, column) = (4.07, "10 Yr")
# (r̄, column) = (4.43, "20 Yr")
# (r̄, column) = (4.3, "30 Yr")
# (r̄, column) = (5.55, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.45, "3 Mo")
# (r̄, column) = (5.37, "4 Mo")
# (r̄, column) = (5.16, "6 Mo")
# (r̄, column) = (4.65, "1 Yr")
# (r̄, column) = (4.14, "2 Yr")
# (r̄, column) = (3.92, "3 Yr")
# (r̄, column) = (3.84, "5 Yr")
# (r̄, column) = (3.91, "7 Yr")
# (r̄, column) = (3.96, "10 Yr")
# (r̄, column) = (4.32, "20 Yr")
# (r̄, column) = (4.2, "30 Yr")
# (r̄, column) = (5.54, "1 Mo")
# (r̄, column) = (5.47, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.38, "4 Mo")
# (r̄, column) = (5.22, "6 Mo")
# (r̄, column) = (4.75, "1 Yr")
# (r̄, column) = (4.26, "2 Yr")
# (r̄, column) = (4.02, "3 Yr")
# (r̄, column) = (3.9, "5 Yr")
# (r̄, column) = (3.95, "7 Yr")
# (r̄, column) = (3.98, "10 Yr")
# (r̄, column) = (4.32, "20 Yr")
# (r̄, column) = (4.18, "30 Yr")
# (r̄, column) = (5.53, "1 Mo")
# (r̄, column) = (5.46, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.39, "4 Mo")
# (r̄, column) = (5.23, "6 Mo")
# (r̄, column) = (4.82, "1 Yr")
# (r̄, column) = (4.37, "2 Yr")
# (r̄, column) = (4.1, "3 Yr")
# (r̄, column) = (3.99, "5 Yr")
# (r̄, column) = (4.01, "7 Yr")
# (r̄, column) = (4.04, "10 Yr")
# (r̄, column) = (4.35, "20 Yr")
# (r̄, column) = (4.2, "30 Yr")
# (r̄, column) = (5.53, "1 Mo")
# (r̄, column) = (5.46, "2 Mo")
# (r̄, column) = (5.47, "3 Mo")
# (r̄, column) = (5.38, "4 Mo")
# (r̄, column) = (5.24, "6 Mo")
# (r̄, column) = (4.82, "1 Yr")
# (r̄, column) = (4.36, "2 Yr")
# (r̄, column) = (4.09, "3 Yr")
# (r̄, column) = (3.97, "5 Yr")
# (r̄, column) = (4.0, "7 Yr")
# (r̄, column) = (4.02, "10 Yr")
# (r̄, column) = (4.33, "20 Yr")
# (r̄, column) = (4.18, "30 Yr")
# (r̄, column) = (5.54, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.49, "3 Mo")
# (r̄, column) = (5.39, "4 Mo")
# (r̄, column) = (5.24, "6 Mo")
# (r̄, column) = (4.82, "1 Yr")
# (r̄, column) = (4.36, "2 Yr")
# (r̄, column) = (4.11, "3 Yr")
# (r̄, column) = (3.97, "5 Yr")
# (r̄, column) = (3.99, "7 Yr")
# (r̄, column) = (4.01, "10 Yr")
# (r̄, column) = (4.33, "20 Yr")
# (r̄, column) = (4.17, "30 Yr")
# (r̄, column) = (5.54, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.47, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.24, "6 Mo")
# (r̄, column) = (4.84, "1 Yr")
# (r̄, column) = (4.4, "2 Yr")
# (r̄, column) = (4.17, "3 Yr")
# (r̄, column) = (4.02, "5 Yr")
# (r̄, column) = (4.04, "7 Yr")
# (r̄, column) = (4.05, "10 Yr")
# (r̄, column) = (4.37, "20 Yr")
# (r̄, column) = (4.21, "30 Yr")
# (r̄, column) = (5.56, "1 Mo")
# (r̄, column) = (5.48, "2 Mo")
# (r̄, column) = (5.48, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.25, "6 Mo")
# (r̄, column) = (4.85, "1 Yr")
# (r̄, column) = (4.38, "2 Yr")
# (r̄, column) = (4.14, "3 Yr")
# (r̄, column) = (3.97, "5 Yr")
# (r̄, column) = (3.99, "7 Yr")
# (r̄, column) = (3.99, "10 Yr")
# (r̄, column) = (4.3, "20 Yr")
# (r̄, column) = (4.13, "30 Yr")
# (r̄, column) = (5.54, "1 Mo")
# (r̄, column) = (5.54, "2 Mo")
# (r̄, column) = (5.48, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.25, "6 Mo")
# (r̄, column) = (4.81, "1 Yr")
# (r̄, column) = (4.33, "2 Yr")
# (r̄, column) = (4.07, "3 Yr")
# (r̄, column) = (3.9, "5 Yr")
# (r̄, column) = (3.92, "7 Yr")
# (r̄, column) = (3.91, "10 Yr")
# (r̄, column) = (4.21, "20 Yr")
# (r̄, column) = (4.05, "30 Yr")
# (r̄, column) = (5.55, "1 Mo")
# (r̄, column) = (5.54, "2 Mo")
# (r̄, column) = (5.46, "3 Mo")
# (r̄, column) = (5.41, "4 Mo")
# (r̄, column) = (5.24, "6 Mo")
# (r̄, column) = (4.8, "1 Yr")
# (r̄, column) = (4.33, "2 Yr")
# (r̄, column) = (4.09, "3 Yr")
# (r̄, column) = (3.93, "5 Yr")
# (r̄, column) = (3.95, "7 Yr")
# (r̄, column) = (3.95, "10 Yr")
# (r̄, column) = (4.25, "20 Yr")
# (r̄, column) = (4.08, "30 Yr")
# 153×13 Matrix{Float64}:
#  99.7944  99.5893  99.3846  100.0  …  100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0  …  100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0  …  100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#   ⋮                                ⋱                  ⋮
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0  …  100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0  …  100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0
#  99.7944  99.5893  99.3846  100.0     100.0  100.0  100.0  100.0  100.0

# %% [markdown]
# ## Task 2: Let's compute and analyze our own recession indicator
# Fill me in

# %% [markdown]
# ## Disclaimer and Risks
# __This content is offered solely for training and informational purposes__. No offer or solicitation to buy or sell securities or derivative products or any investment or trading advice or strategy is made, given, or endorsed by the teaching team.
#
# __Trading involves risk__. Carefully review your financial situation before investing in securities, futures contracts, options, or commodity interests. Past performance, whether actual or indicated by historical tests of strategies, is no guarantee of future performance or success. Trading is generally inappropriate for someone with limited resources, investment or trading experience, or a low-risk tolerance.  Only risk capital that is not required for living expenses.
#
# __You are fully responsible for any investment or trading decisions you make__. Such decisions should be based solely on evaluating your financial circumstances, investment or trading objectives, risk tolerance, and liquidity needs.
